# %% [markdown]
# # Load model

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
import os
import glob
import shutil
import sys
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from IPython.display import Image
from tensorflow.keras import callbacks

# %%
import os
# os.path.abspath('/media/tohn/SSD/Efficient_USAI')
os.chdir('/media/tohn/SSD/FP-B_Nor_ABnor_Network')
# !ls
  #choose gpu on processing 
os.environ["CUDA_VISIBLE_DEVICES"]="0" # second gpu
# Out:
# content

# %%
import os
# %cd content
if not os.path.isdir("efficientnet_keras_transfer_learning"):
  # !git clone https://github.com/Tony607/efficientnet_keras_transfer_learning
# %cd efficientnet_keras_transfer_learning/
# Out:
# /media/tohn/SSD/FP-B_Nor_ABnor_Network/content
# /media/tohn/SSD/FP-B_Nor_ABnor_Network/content/efficientnet_keras_transfer_learning

# %%
import sys
sys.path.append('/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})
# Out:
# Using TensorFlow backend.

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning/models/Sub_b0_c11_250_R2.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Model)      (None, 5, 5, 1280)        4049564
# _________________________________________________________________
# gap (GlobalMaxPooling2D)     (None, 1280)              0
# _________________________________________________________________
# dropout_out (Dropout)        (None, 1280)              0
# _________________________________________________________________
# fc_out (Dense)               (None, 13)                16653
# =================================================================
# Total params: 4,066,217
# Trainable params: 798,093
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %%
model.pop()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Model)      (None, 5, 5, 1280)        4049564
# _________________________________________________________________
# gap (GlobalMaxPooling2D)     (None, 1280)              0
# _________________________________________________________________
# dropout_out (Dropout)        (None, 1280)              0
# =================================================================
# Total params: 4,049,564
# Trainable params: 781,440
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %% [markdown]
# ### สร้าง Network ใหม่

# %%
model2 = models.Sequential()
model2.add(model)
model2.add(layers.Dense(1, activation='sigmoid', name="fc_out"))        #class --> 2
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 1280)              4049564
# _________________________________________________________________
# fc_out (Dense)               (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 782,721
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %% [markdown]
# ### จัดการ data

# %%
import pandas as pd
import numpy as np
df = pd.read_csv (r'/home/yupaporn/EfficientNet_USAI/final_training_table.csv')
# df =df[df['Path Crop'] != 'None']
# df.dropna()
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0           2053          2053    40           P3          P31    Normal
# 1           3682          3682   194           P3          P31    Normal
# 2           2000          2000    59           P3          P31    Normal
# 3           3090          3090   105           P3          P31    Normal
# 4           2001          2001    14           P3          P31    Normal
# 5           2594          2594    93           P3          P31    Normal
# 6           2586          2586    84           P3          P31    Normal
# 7           2031          2031    35           P3          P31    Normal
# 8           3667          3667   173           P3          P31    Normal
# 9           3659          3659   180           P3          P31    Normal
# 10          2593          2593    92           P3          P31    Normal
# 11          3696          3696   176           P3          P31    Normal
# 12          2018          2018    18           P3          P31    Normal
# 13          2039          2039    58           P3          P31    Normal
# 14          2037          2037    26           P3          P31    Normal
# 15          3665          3665   162           P3          P31    Normal
# 16          2575          2575    72           P3          P31    Normal
# 17          2061          2061    49           P3          P31    Normal
# 18          2015          2015    19           P3          P31    Normal
# 19          2608          2608    86           P3          P31    Normal
# 20          3059          3059   138           P3          P31    Normal
# 21          3690          3690   182           P3          P31    Normal
# 22          3089          3089   112           P3          P31    Normal
# 23          2083          2083    16           P3          P31    Normal
# 24          3105          3105   113           P3          P31    Normal
# 25          2587          2587    70           P3          P31    Normal
# 26          3660          3660   177           P3          P31    Normal
# 27          2604          2604    90           P3          P31    Normal
# 28          3077          3077   131           P3          P31    Normal
# 29          2602          2602    68           P3          P31    Normal
# ...          ...           ...   ...          ...          ...       ...
# 2478        1746          1746    66           P7          P72  Abnormal
# 2479        1677          1677    58           P7          P72  Abnormal
# 2480        1752          1752    41           P7          P72  Abnormal
# 2481        1758          1758    39           P7          P72  Abnormal
# 2482        1686          1686    93           P7          P72  Abnormal
# 2483        1717          1717    67           P7          P72  Abnormal
# 2484        1736          1736    50           P7          P72  Abnormal
# 2485        1690          1690    69           P7          P72  Abnormal
# 2486        1727          1727    92           P7          P72  Abnormal
# 2487        1721          1721    47           P7          P72  Abnormal
# 2488        1701          1701    26           P7          P72  Abnormal
# 2489        1764          1764    83           P7          P72  Abnormal
# 2490        1766          1766    95           P7          P72  Abnormal
# 2491        1739          1739    15           P7          P72  Abnormal
# 2492        1743          1743    55           P7          P72  Abnormal
# 2493        1734          1734    53           P7          P72  Abnormal
# 2494        1740          1740    74           P7          P72  Abnormal
# 2495        1754          1754    33           P7          P72  Abnormal
# 2496        1728          1728    52           P7          P72  Abnormal
# 2497        1697          1697    40           P7          P72  Abnormal
# 2498        1765          1765    63           P7          P72  Abnormal
# 2499        1732          1732    45           P7          P72  Abnormal
# 2500        1712          1712    60           P7          P72  Abnormal
# 2501        1725          1725    31           P7          P72  Abnormal
# 2502        1716          1716    91           P7          P72  Abnormal
# 2503        1699          1699    51           P7          P72  Abnormal
# 2504        1709          1709    81           P7          P72  Abnormal
# 2505        1706          1706    94           P7          P72  Abnormal
# 2506        1708          1708    72           P7          P72  Abnormal
# 2507        1747          1747    85           P7          P72  Abnormal
#
#      Sub_class                                          Path Full  \
# 0       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 4       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 7       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 9       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 10      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 11      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 12      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 16      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 17      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 20      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 21      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 22      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 23      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 25      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 26      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 27      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 28      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 29      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# ...        ...                                                ...
# 2478      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2479      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2480      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2481      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2482      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2483      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2484      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2485      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2486      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2487      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2488      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2489      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2490      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2491      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2492      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2493      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2494      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2495      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2496      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2497      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2498      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2499      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2500      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2501      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2502      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2503      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2504      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2505      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2506      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2507      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 1     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 3     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 4     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 5     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 7     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 8     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 9     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 10    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 11    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 12    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 13    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 14    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 15    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 16    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 17    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 18    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 19    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 20    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 21    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 22    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 23    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 24    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 25    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 26    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 27    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 28    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 29    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# ...                                                 ...
# 2478  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2479  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2480  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2481  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2482  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2483  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2484  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2485  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2486  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2487  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2488  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2489  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2490  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2491  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2492  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2493  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2494  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2495  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2496  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2497  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2498  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2499  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2500  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2501  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2502  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2503  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2504  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2505  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2506  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2507  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
# [2508 rows x 9 columns]

# %%
#select data 
df1 = df.loc[(df['Abs Position']  == 'P3' ) | (df['Abs Position']  == 'P4')]
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0           2053          2053    40           P3          P31    Normal
# 1           3682          3682   194           P3          P31    Normal
# 2           2000          2000    59           P3          P31    Normal
# 3           3090          3090   105           P3          P31    Normal
# 4           2001          2001    14           P3          P31    Normal
# 5           2594          2594    93           P3          P31    Normal
# 6           2586          2586    84           P3          P31    Normal
# 7           2031          2031    35           P3          P31    Normal
# 8           3667          3667   173           P3          P31    Normal
# 9           3659          3659   180           P3          P31    Normal
# 10          2593          2593    92           P3          P31    Normal
# 11          3696          3696   176           P3          P31    Normal
# 12          2018          2018    18           P3          P31    Normal
# 13          2039          2039    58           P3          P31    Normal
# 14          2037          2037    26           P3          P31    Normal
# 15          3665          3665   162           P3          P31    Normal
# 16          2575          2575    72           P3          P31    Normal
# 17          2061          2061    49           P3          P31    Normal
# 18          2015          2015    19           P3          P31    Normal
# 19          2608          2608    86           P3          P31    Normal
# 20          3059          3059   138           P3          P31    Normal
# 21          3690          3690   182           P3          P31    Normal
# 22          3089          3089   112           P3          P31    Normal
# 23          2083          2083    16           P3          P31    Normal
# 24          3105          3105   113           P3          P31    Normal
# 25          2587          2587    70           P3          P31    Normal
# 26          3660          3660   177           P3          P31    Normal
# 27          2604          2604    90           P3          P31    Normal
# 28          3077          3077   131           P3          P31    Normal
# 29          2602          2602    68           P3          P31    Normal
# ...          ...           ...   ...          ...          ...       ...
# 1738        1383          1383    70           P4          P42  Abnormal
# 1739        1460          1460    41           P4          P42  Abnormal
# 1740        1545          1545    22           P4          P42  Abnormal
# 1741        1071          1071    40           P4          P42  Abnormal
# 1742         352           352    18           P4          P42  Abnormal
# 1743           5             5    13           P4          P42  Abnormal
# 1744         629           629    96           P4          P42  Abnormal
# 1745         210           210    16           P4          P42  Abnormal
# 1746         650           650    12           P4          P42  Abnormal
# 1747        1518          1518    20           P4          P42  Abnormal
# 1748         998           998    29           P4          P42  Abnormal
# 1749        1403          1403    68           P4          P42  Abnormal
# 1750         452           452    54           P4          P42  Abnormal
# 1751        1432          1432    32           P4          P42  Abnormal
# 1752        1374          1374    13           P4          P42  Abnormal
# 1753         637           637    53           P4          P42  Abnormal
# 1754         552           552    16           P4          P42  Abnormal
# 1755        1436          1436    98           P4          P42  Abnormal
# 1756        1601          1601    18           P4          P42  Abnormal
# 1757         507           507    42           P4          P42  Abnormal
# 1758        1443          1443    74           P4          P42  Abnormal
# 1759         169           169    34           P4          P42  Abnormal
# 1760         105           105    23           P4          P42  Abnormal
# 1761        1520          1520    30           P4          P42  Abnormal
# 1762        1006          1006    52           P4          P42  Abnormal
# 1763        1484          1484    45           P4          P42  Abnormal
# 1764        1504          1504    74           P4          P42  Abnormal
# 1765          31            31    54           P4          P42  Abnormal
# 2160        3719          3719   195           P3          P32    Normal
# 2161        1078          1078    58           P3          P32  Abnormal
#
#      Sub_class                                          Path Full  \
# 0       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 4       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 7       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 9       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 10      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 11      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 12      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 16      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 17      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 20      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 21      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 22      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 23      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 25      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 26      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 27      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 28      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 29      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# ...        ...                                                ...
# 1738     AB081  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1739     AB081  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1740     AB082  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1741      AB05  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1742      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1743      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1744      AB02  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1745      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1746      AB02  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1747     AB082  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1748      AB05  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1749     AB081  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1750      AB02  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1751     AB081  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1752     AB081  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1753      AB02  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1754      AB02  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1755     AB081  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1756     AB083  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1757      AB02  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1758     AB081  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1759      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1760      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1761     AB082  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1762      AB05  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1763     AB082  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1764   AB082_1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1765      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2160    Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2161      AB05  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 1     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 3     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 4     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 5     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 7     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 8     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 9     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 10    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 11    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 12    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 13    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 14    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 15    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 16    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 17    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 18    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 19    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 20    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 21    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 22    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 23    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 24    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 25    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 26    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 27    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 28    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 29    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# ...                                                 ...
# 1738  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1739  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1740  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1741  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1742  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1743  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1744  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1745  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1746  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1747  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1748  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1749  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1750  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1751  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1752  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1753  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1754  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1755  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1756  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1757  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1758  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1759  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1760  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1761  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1762  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1763  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1764  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1765  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2160  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2161  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
# [806 rows x 9 columns]

# %%
msk = np.random.rand(len(df1)) < 0.9
test = df1[~msk] #56
train= df1[msk]#692

# %%
print(test.shape)
print(train.shape)
print(df1.shape)
# Out:
# (74, 9)
# (732, 9)
# (806, 9)

# %% [markdown]
# #### การเเบ่งข้อมูล train/validation/test sets

# %%
# The directory where we will
base_dir = './data/views'
os.makedirs(base_dir, exist_ok=True)

# Directories for our training,
# validation and test splits
train_dir = os.path.join(base_dir, 'train')
os.makedirs(train_dir, exist_ok=True)

validation_dir = os.path.join(base_dir, 'validation')
os.makedirs(train_dir, exist_ok=True)

# %%
# Directory with our training cat pictures
train_Nor_dir = os.path.join(train_dir, 'Normal')
os.makedirs(train_Nor_dir, exist_ok=True)
# Directory with our training cat pictures
train_ABn_dir = os.path.join(train_dir, 'ABnormal')
os.makedirs(train_ABn_dir, exist_ok=True)

# Directory with our training cat pictures
validation_Nor_dir = os.path.join(validation_dir, 'Normal')
os.makedirs(validation_Nor_dir, exist_ok=True)
# Directory with our training cat pictures
validation_ABn_dir = os.path.join(validation_dir, 'ABnormal')
os.makedirs(validation_ABn_dir, exist_ok=True)

#Path images of train
Nor_train = train[train['Class']=='Normal']
Nor_path_train = Nor_train['Path Crop'].tolist() 
ABn_train = train[train['Class']=='Abnormal']
ABn_path_train = ABn_train['Path Crop'].tolist() 

Nor_validation = test[test['Class']=='Normal']
Nor_path_validation = Nor_validation['Path Crop'].tolist() 
ABn_validation = test[test['Class']=='Abnormal']
ABn_path_validation= ABn_validation['Path Crop'].tolist() 

#Train
fnames = Nor_path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)
    
fnames = ABn_path_train  
for fname in fnames:
    dst = os.path.join(train_ABn_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)
  
 #Validation
fnames = Nor_path_validation 
for fname in fnames:
    dst = os.path.join(validation_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)

fnames = ABn_path_validation
for fname in fnames:
    dst = os.path.join(validation_ABn_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)

# %%
print('Train images total : ',len(Nor_path_train)+len(ABn_path_train))
print('Validation images total : ',len(ABn_path_validation)+len(Nor_path_validation))
print('Total images : ',len(Nor_path_train)+len(ABn_path_train)+len(ABn_path_validation)+len(Nor_path_validation))
# Out:
# Train images total :  673
# Validation images total :  75
# Total images :  748

# %% [markdown]
# #### Hyper parameters

# %%
batch_size = 50 

width = 150 
height = 150 
input_shape = (height, width, 3) #ขนาด image enter

epochs = 20  #จำนวนรอบในการ Train
NUM_TRAIN = 2251  # จำนวนภาพ Train
NUM_TEST = 257 #จำนวนภาพ Test
dropout_rate = 0.2 #คือการปิดบาง Node หรือเรียกว่าทำการ Drop Out ไป ซึ่งขึ้นกับการตั้งค่าว่าจะให้ลืมไปกี่เปอร์เซนต์ดี ช่วยในการแก้ปัญหา Overfitting

# %% [markdown]
# #### Setting data augmentation

# %%
# data augmentation เพื่อลดโอกาสการเกิด overfitting

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
      rescale=1./255, # image input 0-255 --> 0-1 เปลี่ยนค่าสี
      rotation_range=40, # หมุนภาพในองศา
      width_shift_range=0.2, #เปลี่ยนความกว้าง
      height_shift_range=0.2, #ปลี่ยนความสูง
      shear_range=0.2, #ทำให้ภาพเบี้ยว
      zoom_range=0.2, #ซุม image มากสุด 20%
      horizontal_flip=False, #พลิกภาพแบบสุ่มตามแนวนอน
      fill_mode='nearest') 

# Note that the validation data should not be augmented!
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to target height and width.
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        # Since we use categorical_crossentropy loss, we need categorical labels
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        class_mode='binary')
# Out:
# Found 673 images belonging to 2 classes.
# Found 75 images belonging to 2 classes.

# %% [markdown]
# #### Training

# %%
model2.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=2e-5),
              metrics=['acc'])

#history คือตัวแปรที่จะทำการเก็บประวัติการ Train Model ของเรา
#คำสั่ง Train
history = model2.fit_generator(
      train_generator,#โหลดdataเข้ามา
      steps_per_epoch= NUM_TRAIN //batch_size,
      epochs=epochs,
      validation_data=validation_generator, #validation_data=(x_valid, y_valid): ใส่ data ที่เราแยกไว้เพื่อดูผล Model ว่าเกิด Overfitting เริ่มที่จุดใด
      validation_steps= NUM_TEST //batch_size,
      verbose=1, #โชว์ผลลัพธ์ 0:ปิด
      use_multiprocessing=True, #ใช้ GPU หลายตัว
      workers=1) #ทำพร้อมกันที่ละ 4 ตัว
# Out:
# WARNING:tensorflow:From <ipython-input-19-d67f93889282>:15: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 10/45 [=====>........................] - ETA: 19s - loss: 0.9105 - acc: 0.5476
# Process Keras_worker_ForkPoolWorker-1:
# Traceback (most recent call last):
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py", line 662, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/site-packages/keras_preprocessing/image/iterator.py", line 65, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/site-packages/keras_preprocessing/image/iterator.py", line 230, in _get_batches_of_transformed_samples
#     interpolation=self.interpolation)
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/site-packages/keras_preprocessing/image/utils.py", line 138, in load_img
#     img = img.resize(width_height_tuple, resample)
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/site-packages/PIL/Image.py", line 1886, in resize
#     self.load()
#   File "/home/yupaporn/miniconda3/envs/eff/lib/python3.6/site-packages/PIL/ImageFile.py", line 251, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt

# %% [markdown]
# # Test Predict

# %%
import pandas as pd
import os

# %%
  #choose gpu on processing 
os.environ["CUDA_VISIBLE_DEVICES"]="0" # second gpu

# %%
df0 = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_350_.csv')
df01 = df0[(df0['Path Crop']!='None' )&(df0['Path Crop']!='Nan')]
#select data 
df02 = df01.loc[(df01['Abs Position']  == 'P3' ) | (df01['Abs Position']  == 'P4')]

# %%
a = df02[df02['Case'].between(1, 10)]
print(a.shape)
print('Normal: ',a[a['Class']=='Normal'].shape)
print('Abnormal: ',a[a['Class']=='Abnormal'].shape)
# a1 = a['Path Crop'].tolist() 
# a1[0]
# Out:
# (152, 8)
# Normal:  (41, 8)
# Abnormal:  (111, 8)

# %% [markdown]
# ### Load model

# %%
import sys
sys.path.append('/media/tohn/SSD/FP-B_Nor_ABnor_Network/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})
# Out:
# Using TensorFlow backend.

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/FP-B_Nor_ABnor_Network/content/efficientnet_keras_transfer_learning/models/FP_B_small.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 1280)              4049564
# _________________________________________________________________
# fc_out (Dense)               (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 782,721
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %% [markdown]
# ### Prediction

# %%
width = 150 
height = 150 
input_shape = (height, width, 3)

# %%
from tensorflow.keras.preprocessing import image
import pandas as pd

# %%
def predict_image(img_path):
    # Read the image and resize it
    img = image.load_img(img_path, target_size=(height, width))
    # Convert it to a Numpy array with target shape.
    x = image.img_to_array(img)
    # Reshape
    x = x.reshape((1,) + x.shape)
    x /= 255.
    result = model.predict([x])[0][0]
    if result > 0.5:
        classs = "Normal"
    else:
        classs = "Abnormal"
        result = 1 - result
    return classs,result
classe =['Normal','Abnormal']
results = list()
# predlist,problist = list(), list()

for i in classe:
    img_path =a[a['Class']==i]['Path Crop'].tolist()
    for j in img_path:
        classs,result = predict_image(j)
        results.append({'2Actual':i,'3Predicted':classs, '4Class_prob':result,'path':j})

# %%
result = pd.DataFrame(results)
result
# Out:
#       2Actual 3Predicted  4Class_prob  \
# 0      Normal     Normal     1.000000
# 1      Normal     Normal     0.944473
# 2      Normal     Normal     0.999463
# 3      Normal     Normal     0.999994
# 4      Normal     Normal     0.999929
# 5      Normal     Normal     0.999867
# 6      Normal     Normal     1.000000
# 7      Normal     Normal     0.943072
# 8      Normal     Normal     0.999842
# 9      Normal     Normal     0.989920
# 10     Normal     Normal     0.999943
# 11     Normal     Normal     0.999977
# 12     Normal     Normal     0.999956
# 13     Normal     Normal     1.000000
# 14     Normal     Normal     0.999945
# 15     Normal     Normal     0.999980
# 16     Normal     Normal     0.999999
# 17     Normal     Normal     0.999999
# 18     Normal     Normal     0.997451
# 19     Normal     Normal     0.999873
# 20     Normal     Normal     0.998205
# 21     Normal     Normal     0.999962
# 22     Normal     Normal     0.998018
# 23     Normal     Normal     0.999996
# 24     Normal     Normal     0.999895
# 25     Normal     Normal     1.000000
# 26     Normal     Normal     1.000000
# 27     Normal     Normal     0.999495
# 28     Normal     Normal     1.000000
# 29     Normal     Normal     1.000000
# ..        ...        ...          ...
# 122  Abnormal   Abnormal     0.994684
# 123  Abnormal   Abnormal     0.999374
# 124  Abnormal     Normal     0.848340
# 125  Abnormal   Abnormal     0.979111
# 126  Abnormal   Abnormal     0.998951
# 127  Abnormal   Abnormal     0.914344
# 128  Abnormal     Normal     0.714280
# 129  Abnormal   Abnormal     0.929324
# 130  Abnormal   Abnormal     0.982019
# 131  Abnormal   Abnormal     0.942140
# 132  Abnormal   Abnormal     0.985047
# 133  Abnormal   Abnormal     0.965392
# 134  Abnormal     Normal     0.998372
# 135  Abnormal   Abnormal     0.996286
# 136  Abnormal     Normal     0.997078
# 137  Abnormal     Normal     0.998372
# 138  Abnormal   Abnormal     0.972188
# 139  Abnormal     Normal     0.937054
# 140  Abnormal     Normal     0.559077
# 141  Abnormal     Normal     0.946514
# 142  Abnormal   Abnormal     0.669250
# 143  Abnormal     Normal     0.946514
# 144  Abnormal     Normal     0.945723
# 145  Abnormal   Abnormal     0.997314
# 146  Abnormal   Abnormal     0.853281
# 147  Abnormal   Abnormal     0.881667
# 148  Abnormal   Abnormal     0.979632
# 149  Abnormal   Abnormal     0.999999
# 150  Abnormal   Abnormal     0.846288
# 151  Abnormal   Abnormal     0.999998
#
#                                                   path
# 0    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ..                                                 ...
# 122  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 123  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 124  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 125  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 126  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 127  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 128  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 129  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 130  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 131  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 132  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 133  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 134  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 135  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 136  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 137  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 138  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 139  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 140  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 141  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 142  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 143  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 144  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 145  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 146  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 147  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 148  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 149  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 150  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 151  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
# [152 rows x 4 columns]

# %%
# os.chdir( '/home/yupaporn/codes/USAI/')
# result.to_csv('predict_FP_B.csv')

# %% [markdown]
# # Visualization

# %%
data_train = result

# %%
#เช็คคลาสใน Predicted
pred_class = set(data_train['3Predicted'])
print('Predicted : ',len(pred_class))
print(pred_class)
#เช็คคลาสใน Actual
classe = set(data_train['2Actual'])
print('Actual : ',len(classe))
print(classe)
# Out:
# Predicted :  2
# {'Normal', 'Abnormal'}
# Actual :  2
# {'Normal', 'Abnormal'}

# %% [markdown]
# ### Confusion matrix

# %%
act = data_train['2Actual'].array
pred = data_train['3Predicted'].array

# %%
classes =['Abnormal', 'Normal']

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
cmat = confusion_matrix(act, pred, classes)
# print('fan classifier accuracy = {}%'.format((100.*numpy.trace(cmat))/(numpy.sum(cmat))))
print('fan classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))
# Out:
# fan classifier accuracy = 85.52631578947368%
# /home/yupaporn/miniconda3/envs/eff/lib/python3.6/site-packages/sklearn/utils/validation.py:71: FutureWarning: Pass labels=['Abnormal', 'Normal'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)

# %%
#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
# confusion_matrix(act, pred)
print(classification_report(act, pred))#performance
# Out:
#               precision    recall  f1-score   support
#
#     Abnormal       1.00      0.80      0.89       111
#       Normal       0.65      1.00      0.79        41
#
#     accuracy                           0.86       152
#    macro avg       0.83      0.90      0.84       152
# weighted avg       0.91      0.86      0.86       152

# %%
data = {'Predicted' : pred, 'Actual': act}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Predicted'],df['Actual'],rownames=['Predicted'],colnames=['Actual'])
conf_mat
# Out:
# Actual     Abnormal  Normal
# Predicted
# Abnormal         89       0
# Normal           22      41

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_xlabel('True label',fontsize=18)
ax.set_yabel('Predicted label',fontsize=18)


# os.chdir( '/home/yupaporn/EfficientNet_USAI/')
# plt.savefig('ConfusionMatrix.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-d2ca4a6c114e> in <module>
#      10 ax.set_title('Confusion matrix',fontsize=20)
#      11 ax.set_xlabel('True label',fontsize=18)
# ---> 12 ax.set_yabel('Predicted label',fontsize=18)
#      13
#      14
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_yabel'

# %% [markdown]
# ### ROC Curve

# %%
import numpy as np
# classes =['P1','P2','P3','P4','P5','P6','P7','P8']
# classes =['P2']
classes =['Abnormal', 'Normal']
threshold = np.arange(0.0, 1.002, 0.001)

TN, FP, FN, TP = list(),list(),list(),list()
precision, recall, ACC, TPR, FPR, SPEC = list(),list(),list(),list(),list(),list()

for i in threshold:
    TN0, FP0, FN0, TP0 = list(),list(),list(),list()
    precision0, recall0, ACC0, TPR0, FPR0, SPEC0 = list(),list(),list(),list(),list(),list()
    
    for j in classes:
        tn,fp,fn,tp = confusion_matrix_all(data_train,j,i) 
        try:
            pre = tp/(tp+fp)
            re= tp/(tp+fn)
            acc = (tp+tn)/(tp+tn+fp+fn)
            tpr = tp/(tp+fn)
            fpr = fp/(fp+tn)
            spec = 1-(tn/(tn+fp))
        except ZeroDivisionError:
            pre,re,acc,tpr,fpr,spec =1,0,0,0,0,0      
            
        TP0.append(tp)
        TN0.append(tn)
        FP0.append(fp)
        FN0.append(fn)
        precision0.append(pre)
        recall0.append(re)
        ACC0.append(acc)
        TPR0.append(re)
        FPR0.append(fpr)       
        SPEC0.append(spec)
        
    precision.append(precision0)
    recall.append(recall0)
    ACC.append(ACC0)
    TPR.append(TPR0)
    FPR.append(FPR0)       
    SPEC.append(SPEC0)
# Out:
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# (
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:62: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#  41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 89 , 22 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 22 , 89 )
# ( 89 , 22 , 0 , 41 )
# ...
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 34 , 77 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 35 , 76 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 35 , 76 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 35 , 76 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 35 , 76 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 35 , 76 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 35 , 76 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 36 , 75 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 36 , 75 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 36 , 75 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 36 , 75 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 36 , 75 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 36 , 75 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 0 , 41 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 37 , 74 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 38 , 73 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 38 , 73 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 38 , 73 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 38 , 73 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 38 , 73 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 38 , 73 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 38 , 73 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 39 , 72 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 95 , 16 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 96 , 15 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 96 , 15 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 40 , 71 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 96 , 15 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 41 , 70 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 97 , 14 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 41 , 70 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 99 , 12 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 42 , 69 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 99 , 12 , 1 , 40 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 42 , 69 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 99 , 12 , 2 , 39 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 42 , 69 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 99 , 12 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 43 , 68 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 100 , 11 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 43 , 68 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 43 , 68 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 43 , 68 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 43 , 68 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 43 , 68 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 102 , 9 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 45 , 66 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 46 , 65 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 46 , 65 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 46 , 65 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 46 , 65 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 47 , 64 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 47 , 64 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 47 , 64 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 48 , 63 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 48 , 63 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 48 , 63 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 48 , 63 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 48 , 63 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 48 , 63 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 48 , 63 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 50 , 61 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 50 , 61 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 103 , 8 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 50 , 61 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 51 , 60 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 51 , 60 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 51 , 60 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 53 , 58 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 53 , 58 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 54 , 57 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 55 , 56 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 104 , 7 , 4 , 37 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 55 , 56 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 105 , 6 , 5 , 36 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 55 , 56 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 105 , 6 , 5 , 36 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 57 , 54 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 105 , 6 , 5 , 36 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 59 , 52 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 107 , 4 , 5 , 36 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 61 , 50 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 107 , 4 , 6 , 35 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 63 , 48 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 107 , 4 , 6 , 35 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 64 , 47 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 107 , 4 , 6 , 35 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 67 , 44 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 107 , 4 , 6 , 35 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 71 , 40 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 108 , 3 , 7 , 34 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 77 , 34 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 110 , 1 , 9 , 32 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 111 , 0 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 111 , 0 , 36 , 5 )
# ( 41 , 0 , 22 , 89 )
# (TN,FP,FN,TP)
# ( 41 , 0 , 111 , 0 )
# ( 89 , 22 , 0 , 41 )
# (TN,FP,FN,TP)
# ( 111 , 0 , 41 , 0 )

# %%
#average per threshold 
precision1,recall1,ACC1,TPR1,FPR1,SPEC1 = list(),list(),list(),list(),list(),list()
from statistics import *
for m in range(0,len(precision)):
    a1 =mean(precision[m])
    a2 =mean(recall[m])
    a3 =mean(ACC[m])
    a4 =mean(TPR[m])
    a5 =mean(FPR[m])
    a6 =mean(SPEC[m])
    
    precision1.append(a1)
    recall1.append(a2)
    ACC1.append(a3)
    TPR1.append(a4)
    FPR1.append(a5)       
    SPEC1.append(a6)

# %%
#create dataframe
import numpy as np
i = np.arange(len(precision1)) # index for df
roc0 = pd.DataFrame({'Threshold' : pd.Series(threshold, index=i),'Precision' : pd.Series(precision1, index = i),'Recall' : pd.Series(recall1, index = i),'tpr' : pd.Series(TPR1, index = i),'fpr' : pd.Series(FPR1, index = i),'1-Spec' : pd.Series(SPEC1, index = i),  'ACC' : pd.Series(ACC1, index = i)})
roc0 = roc0.fillna(1)

fix_value = [{'Threshold':0.000,'Precision':0.000,'Recall':1.000,'tpr':1.000,'fpr':1.000,'1-Spec':1.000,'ACC':0.000}]
roc0 = roc0.append(fix_value,ignore_index=True,sort=False)
roc0 = roc0.apply(np.roll, shift=1) #move he last row to the first

# %%
import numpy as np
    #Precision & Recall Curve
recall = np.array(roc0['Recall'])
precision = np.array(roc0['Precision'])

import matplotlib.pyplot as plt
from matplotlib import pyplot
lw = 3
fig, ax = plt.subplots(figsize=(10, 7))
plt.axhline(0, lw=2.5, color='black')
plt.axvline(0, lw=2.5, color='black')
# ax.set_facecolor(('w'))
fig.patch.set_facecolor('w')
plt.plot([0, 1], [0.5, 0.5],'c', linestyle='--',lw=2.5)
pyplot.plot(recall, precision, marker='.', lw=lw)
    # axis labels
pyplot.xlabel('Recall',fontsize=18)
pyplot.ylabel('Precision',fontsize=18)
pyplot.title('Precision & Recall',fontsize=20)
    # show the legend
pyplot.legend()
    # show the plot
pyplot.show()


    # calculate the precision-recall auc
from sklearn.metrics import auc
auc_score = auc(recall, precision)
print('PR AUC (area = %0.2f)' % (auc_score))
# Out:
# No handles with labels found to put in legend.
# PR AUC (area = 0.91)

# %%
    #sen VS spec
import numpy as np
sen= np.array(roc0['tpr'])
spec = np.array(roc0['1-Spec'])

from matplotlib import pyplot
lw = 3
fig, ax = plt.subplots(figsize=(10, 7))
plt.axhline(0, lw=2.5, color='black')
plt.axvline(0, lw=2.5, color='black')
fig.patch.set_facecolor('w')
plt.plot([0, 0],[1, 1],'c', linestyle='--',lw=2.5)
pyplot.plot(spec,sen, marker='.',lw=lw)  

    # axis labels
pyplot.xlabel('1-Specificity',fontsize=18)
pyplot.ylabel('Sensitivity',fontsize=18)
pyplot.title('Sensitivity & 1-Specificity',fontsize=20)

    # show the legend
pyplot.legend()
    # show the plot
pyplot.show()


    # calculate the precision-recall auc
from sklearn.metrics import auc
auc_score = auc(spec, sen)
print('PR AUC (area = %0.2f)' % (auc_score))
# Out:
# No handles with labels found to put in legend.
# PR AUC (area = 0.93)

# %%
plot_roc(roc0)
# Out:
# PR AUC (area = 0.91)
# PR ROC (area = 0.93)
# PR AUC (area = 0.93)

# %% [markdown]
# # Function

# %%
def confusion_matrix_all(data_train,classes,threshold):


    #1. manage data  --------------------------------------------------------------------------------------------------------------------------------------------------

    p1 = data_train #Input table
   
    if classes =='Normal':
        act= p1['2Actual'].map({'Normal':1,'Abnormal':0}).values
        pred = p1['3Predicted'].map({'Normal':1,'Abnormal':0}).values
    else:
        act= p1['2Actual'].map({'Normal':0,'Abnormal':1}).values
        pred = p1['3Predicted'].map({'Normal':0,'Abnormal':1}).values

    prob_all = p1['4Class_prob'].to_numpy()

    #2. เงื่อนไข ---------------------------------------------------------------------------------------------------------------------------------------------

    TP,TN,FP,FN,posi_tp,posi_tn,posi_fp,posi_fn = list(), list(), list(), list(),list(), list(), list(), list()
    for i in range(len(act)):
        if act[i] & pred[i]  == 1:
            tp = 1
            po_tp = i
            TP.append(tp)
            posi_tp.append(po_tp)
        elif act[i] == 0: 
            if pred[i]  == 1:
                fp = 1
                po_fp = i
                FP.append(fp)
                posi_fp.append(po_fp)  

        if act[i] == 1: 
            if pred[i]  == 0:
                fn = 1
                po_fn = i
                FN.append(fn)
                posi_fn.append(po_fn) 
        elif act[i] | pred[i]  == 0:
            tn = 1
            po_tn = i
            TN.append(tn)
            posi_tn.append(po_tn)



    print('(',len(TN),',', len(FP),',', len(FN),',', len(TP) ,')')

# 3. threshold ----------------------------------------------------------------

    if  posi_tp or posi_fp  != 0:      
                #Keep only interested TP, FP 
        inter_point = posi_tp+posi_fp
        inter = act[inter_point]
        prob = prob_all[inter_point]

        import numpy as np
        from sklearn.metrics import confusion_matrix

#         threshold = 0
        t = prob >= threshold
        t = np.where(t=='True', 1, t) #repalce True-1,False-0

        tp_new,tn_new,fp_new,fn_new = list(),list(),list(),list()
        for i in range(len(inter)):
            if inter[i] & t[i]  == 1:
                tp0 = 1
                tp_new.append(tp0)

            elif inter[i] == 0: 
                if t[i]  == 1:
                    fp0 = 1
                    fp_new.append(fp0) 

            if inter[i] == 1: 
                if t[i]  == 0:
                    fn0 = 1
                    fn_new.append(fn0)

            elif inter[i] | t[i]  == 0:
                tn0 = 1
                tn_new.append(tn0)  #find  confusion matrix

        if TN.count(1) !=0:
            tn_new = TN.count(1)+tn_new.count(1)
        else : 
            tn_new = tn_new.count(1)    
        if FN.count(1) !=0:
            fn_new = FN.count(1)+fn_new.count(1)
        else :
            fn_new = fn_new.count(1)

        fp_new = fp_new.count(1)
        tp_new = tp_new.count(1)

        print('(TN,FP,FN,TP)')
        print('(',tn_new,',', fp_new,',', fn_new,',', tp_new ,')')

        return tn_new, fp_new, fn_new, tp_new

    else :
        print('(TN,FP,FN,TP)')
        print('(',TN.count(1),',', FP.count(1),',', FN.count(1),',', TP.count(1) ,')')

        return TN.count(1),  FP.count(1), FN.count(1), TP.count(1)

# %%
#Plot ROC
def plot_roc(roc0):
    
    import numpy as np
    #Precision & Recall Curve
    recall = np.array(roc0['Recall'])
    precision = np.array(roc0['Precision'])


    import matplotlib.pyplot as plt
    from matplotlib import pyplot
    lw = 2
    plt.plot([0, 1], [0.5, 0.5], linestyle='--', lw=lw)
    pyplot.plot(recall, precision, marker='.', label='Multiclass')
    # axis labels
    pyplot.xlabel('Recall')
    pyplot.ylabel('Precision')
    pyplot.title('Precision & Recall')
    # show the legend
    pyplot.legend()
    # show the plot
    pyplot.show()


    # calculate the precision-recall auc
    from sklearn.metrics import auc
    auc_score = auc(recall, precision)
    print('PR AUC (area = %0.2f)' % (auc_score))

    #_______________________________________________________________________________________________

    #FPR VS TPR

    import numpy as np
    tpr= np.array(roc0['tpr'])
    fpr = np.array(roc0['fpr'])

    from matplotlib import pyplot

    pyplot.plot(fpr, tpr, marker='.', label='Multiclass')  #กลับด้านทำไม?????
    # axis labels
    pyplot.xlabel('False Positive Rate')
    pyplot.ylabel('true Positive Rate')
    pyplot.title('False Positive Rate & true Positive Rate')
    # show the legend
    pyplot.legend()
    # show the plot
    pyplot.show()


    # calculate the precision-recall auc
    from sklearn.metrics import auc
    auc_score = auc(fpr, tpr)
    print('PR ROC (area = %0.2f)' % (auc_score))

    #_______________________________________________________________________________________________

    #sen VS spec

    import numpy as np
    sen= np.array(roc0['tpr'])
    spec = np.array(roc0['1-Spec'])

    from matplotlib import pyplot
    pyplot.plot(spec,sen, marker='.', label='Multiclass')  

    # axis labels
    pyplot.xlabel('1-Specificity')
    pyplot.ylabel('Sensitivity')
    pyplot.title('Sensitivity & 1-Specificity')

    # show the legend
    pyplot.legend()
    # show the plot
    pyplot.show()


    # calculate the precision-recall auc
    from sklearn.metrics import auc
    auc_score = auc(spec, sen)
    print('PR AUC (area = %0.2f)' % (auc_score))
