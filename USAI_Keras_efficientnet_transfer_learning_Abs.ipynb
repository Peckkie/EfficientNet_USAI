# %%
import pandas as pd
import shutil

# %%
df = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_250.csv')
df
# Out:
#       Unnamed: 0  Case Abs Position Sub Position   Class Sub_class  \
# 0              0     5           P1           P1  Normal    Normal
# 1              1     9           P1           P1  Normal    Normal
# 2              2     6           P1           P1  Normal    Normal
# 3              3     4           P1           P1  Normal    Normal
# 4              4     3           P1           P1  Normal    Normal
# 5              5     2           P1           P1  Normal    Normal
# 6              6     8           P1           P1  Normal    Normal
# 7              7    10           P1           P1  Normal    Normal
# 8              8     7           P1           P1  Normal    Normal
# 9              9     1           P1           P1  Normal    Normal
# 10            10    39           P1           P1  Normal    Normal
# 11            11    54           P1           P1  Normal    Normal
# 12            12    37           P1           P1  Normal    Normal
# 13            13    57           P1           P1  Normal    Normal
# 14            14    58           P1           P1  Normal    Normal
# 15            15    42           P1           P1  Normal    Normal
# 16            16    43           P1           P1  Normal    Normal
# 17            17    33           P1           P1  Normal    Normal
# 18            18    29           P1           P1  Normal    Normal
# 19            19    55           P1           P1  Normal    Normal
# 20            20    48           P1           P1  Normal    Normal
# 21            21    59           P1           P1  Normal    Normal
# 22            22    51           P1           P1  Normal    Normal
# 23            23    11           P1           P1  Normal    Normal
# 24            24    24           P1           P1  Normal    Normal
# 25            25    44           P1           P1  Normal    Normal
# 26            26    35           P1           P1  Normal    Normal
# 27            27    60           P1           P1  Normal    Normal
# 28            28    40           P1           P1  Normal    Normal
# 29            29    30           P1           P1  Normal    Normal
# ...          ...   ...          ...          ...     ...       ...
# 3029        3029   229           P8           P8  Normal    Normal
# 3030        3030   248           P8           P8  Normal    Normal
# 3031        3031   223           P8           P8  Normal    Normal
# 3032        3032   247           P8           P8  Normal    Normal
# 3033        3033   249           P8           P8  Normal    Normal
# 3034        3034   225           P8           P8  Normal    Normal
# 3035        3035   233           P8           P8  Normal    Normal
# 3036        3036   227           P8           P8  Normal    Normal
# 3037        3037   236           P8           P8  Normal    Normal
# 3038        3038   216           P8           P8  Normal    Normal
# 3039        3039   212           P8           P8  Normal    Normal
# 3040        3040   241           P8           P8  Normal    Normal
# 3041        3041   210           P8           P8  Normal    Normal
# 3042        3042   202           P8           P8  Normal    Normal
# 3043        3043   246           P8           P8  Normal    Normal
# 3044        3044   245           P8           P8  Normal    Normal
# 3045        3045   244           P8           P8  Normal    Normal
# 3046        3046   230           P8           P8  Normal    Normal
# 3047        3047   243           P8           P8  Normal    Normal
# 3048        3048   220           P8           P8  Normal    Normal
# 3049        3049   226           P8           P8  Normal    Normal
# 3050        3050   232           P8           P8  Normal    Normal
# 3051        3051   214           P8           P8  Normal    Normal
# 3052        3052   228           P8           P8  Normal    Normal
# 3053        3053   209           P8           P8  Normal    Normal
# 3054        3054   215           P8           P8  Normal    Normal
# 3055        3055   231           P8           P8  Normal    Normal
# 3056        3056   205           P8           P8  Normal    Normal
# 3057        3057   201           P8           P8  Normal    Normal
# 3058        3058   203           P8           P8  Normal    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
# [3059 rows x 8 columns]

# %% [markdown]
# # Clone efficientnet repo

# %%
import os
# os.path.abspath('/media/tohn/SSD/Efficient_USAI')
os.chdir('/media/tohn/SSD/Efficient_USAI')
# !ls
  #choose gpu on processing 
os.environ["CUDA_VISIBLE_DEVICES"]="0" # second gpu
# Out:
# content  data

# %%
import os
# %cd content
if not os.path.isdir("efficientnet_keras_transfer_learning"):
  # !git clone https://github.com/Tony607/efficientnet_keras_transfer_learning
# %cd efficientnet_keras_transfer_learning/
# Out:
# /media/tohn/SSD/Efficient_USAI/content
# /media/tohn/SSD/Efficient_USAI/content/efficientnet_keras_transfer_learning

# %% [markdown]
# # การเเบ่งข้อมูล  train/validation/test sets

# %%
# The directory where we will

base_dir = './data/views'
os.makedirs(base_dir, exist_ok=True)

# Directories for our training,
# validation and test splits
train_dir = os.path.join(base_dir, 'train')
os.makedirs(train_dir, exist_ok=True)
validation_dir = os.path.join(base_dir, 'validation')
os.makedirs(validation_dir, exist_ok=True)
test_dir = os.path.join(base_dir, 'test')
os.makedirs(test_dir, exist_ok=True)

# %%
# classes = ['P1','P2','P31','P32','P41','P42','P51','P52','P6','P62','P71','P72','P8','None']
# len(classes)

# %%
# Directory with our training cat pictures
validation_P1_dir = os.path.join(validation_dir, 'P1')
os.makedirs(validation_P1_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P2_dir = os.path.join(validation_dir, 'P2')
os.makedirs(validation_P2_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P3_dir = os.path.join(validation_dir, 'P3')
os.makedirs(validation_P3_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P4_dir = os.path.join(validation_dir, 'P4')
os.makedirs(validation_P4_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P5_dir = os.path.join(validation_dir, 'P5')
os.makedirs(validation_P5_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P6_dir = os.path.join(validation_dir, 'P6')
os.makedirs(validation_P6_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P7_dir = os.path.join(validation_dir, 'P7')
os.makedirs(validation_P7_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P8_dir = os.path.join(validation_dir, 'P8')
os.makedirs(validation_P8_dir, exist_ok=True)

# Directory with our training cat pictures
train_P1_dir = os.path.join(train_dir, 'P1')
os.makedirs(train_P1_dir, exist_ok=True)
# Directory with our training cat pictures
train_P2_dir = os.path.join(train_dir, 'P2')
os.makedirs(train_P2_dir, exist_ok=True)
# Directory with our training cat pictures
train_P3_dir = os.path.join(train_dir, 'P3')
os.makedirs(train_P3_dir, exist_ok=True)
# Directory with our training cat pictures
train_P4_dir = os.path.join(train_dir, 'P4')
os.makedirs(train_P4_dir, exist_ok=True)
# Directory with our training cat pictures
train_P5_dir = os.path.join(train_dir, 'P5')
os.makedirs(train_P5_dir, exist_ok=True)
# Directory with our training cat pictures
train_P6_dir = os.path.join(train_dir, 'P6')
os.makedirs(train_P6_dir, exist_ok=True)
# Directory with our training cat pictures
train_P7_dir = os.path.join(train_dir, 'P7')
os.makedirs(train_P7_dir, exist_ok=True)
# Directory with our training cat pictures
train_P8_dir = os.path.join(train_dir, 'P8')
os.makedirs(train_P8_dir, exist_ok=True)

# %% [markdown]
# # Copy views images to rain_views_dir

# %%
df1 =df[df['Path Crop'] != 'None']
df1
# Out:
#       Unnamed: 0  Case Abs Position Sub Position   Class Sub_class  \
# 0              0     5           P1           P1  Normal    Normal
# 1              1     9           P1           P1  Normal    Normal
# 2              2     6           P1           P1  Normal    Normal
# 3              3     4           P1           P1  Normal    Normal
# 4              4     3           P1           P1  Normal    Normal
# 5              5     2           P1           P1  Normal    Normal
# 6              6     8           P1           P1  Normal    Normal
# 7              7    10           P1           P1  Normal    Normal
# 8              8     7           P1           P1  Normal    Normal
# 9              9     1           P1           P1  Normal    Normal
# 10            10    39           P1           P1  Normal    Normal
# 11            11    54           P1           P1  Normal    Normal
# 12            12    37           P1           P1  Normal    Normal
# 13            13    57           P1           P1  Normal    Normal
# 14            14    58           P1           P1  Normal    Normal
# 15            15    42           P1           P1  Normal    Normal
# 16            16    43           P1           P1  Normal    Normal
# 17            17    33           P1           P1  Normal    Normal
# 18            18    29           P1           P1  Normal    Normal
# 19            19    55           P1           P1  Normal    Normal
# 20            20    48           P1           P1  Normal    Normal
# 21            21    59           P1           P1  Normal    Normal
# 22            22    51           P1           P1  Normal    Normal
# 23            23    11           P1           P1  Normal    Normal
# 24            24    24           P1           P1  Normal    Normal
# 25            25    44           P1           P1  Normal    Normal
# 26            26    35           P1           P1  Normal    Normal
# 27            27    60           P1           P1  Normal    Normal
# 28            28    40           P1           P1  Normal    Normal
# 29            29    30           P1           P1  Normal    Normal
# ...          ...   ...          ...          ...     ...       ...
# 3029        3029   229           P8           P8  Normal    Normal
# 3030        3030   248           P8           P8  Normal    Normal
# 3031        3031   223           P8           P8  Normal    Normal
# 3032        3032   247           P8           P8  Normal    Normal
# 3033        3033   249           P8           P8  Normal    Normal
# 3034        3034   225           P8           P8  Normal    Normal
# 3035        3035   233           P8           P8  Normal    Normal
# 3036        3036   227           P8           P8  Normal    Normal
# 3037        3037   236           P8           P8  Normal    Normal
# 3038        3038   216           P8           P8  Normal    Normal
# 3039        3039   212           P8           P8  Normal    Normal
# 3040        3040   241           P8           P8  Normal    Normal
# 3041        3041   210           P8           P8  Normal    Normal
# 3042        3042   202           P8           P8  Normal    Normal
# 3043        3043   246           P8           P8  Normal    Normal
# 3044        3044   245           P8           P8  Normal    Normal
# 3045        3045   244           P8           P8  Normal    Normal
# 3046        3046   230           P8           P8  Normal    Normal
# 3047        3047   243           P8           P8  Normal    Normal
# 3048        3048   220           P8           P8  Normal    Normal
# 3049        3049   226           P8           P8  Normal    Normal
# 3050        3050   232           P8           P8  Normal    Normal
# 3051        3051   214           P8           P8  Normal    Normal
# 3052        3052   228           P8           P8  Normal    Normal
# 3053        3053   209           P8           P8  Normal    Normal
# 3054        3054   215           P8           P8  Normal    Normal
# 3055        3055   231           P8           P8  Normal    Normal
# 3056        3056   205           P8           P8  Normal    Normal
# 3057        3057   201           P8           P8  Normal    Normal
# 3058        3058   203           P8           P8  Normal    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
# [3050 rows x 8 columns]

# %%
#Create Path images
val = df1[df1['Case'].between(1, 10)]
train = df1[df1['Case'].between(11, 250)]

#Path images of validation
p1_val = val[val['Abs Position']=='P1' ]
p1_path_val = p1_val['Path Crop'].tolist() 
p2_val = val[val['Abs Position']=='P2' ]
p2_path_val = p2_val['Path Crop'].tolist() 
p3_val = val[val['Abs Position']=='P3' ]
p3_path_val = p3_val['Path Crop'].tolist() 
p4_val = val[val['Abs Position']=='P4' ]
p4_path_val = p4_val['Path Crop'].tolist() 
p5_val = val[val['Abs Position']=='P5' ]
p5_path_val = p5_val['Path Crop'].tolist() 
p6_val = val[val['Abs Position']=='P6' ]
p6_path_val = p6_val['Path Crop'].tolist() 
p7_val = val[val['Abs Position']=='P7' ]
p7_path_val = p7_val['Path Crop'].tolist() 
p8_val = val[val['Abs Position']=='P8' ]
p8_path_val = p8_val['Path Crop'].tolist() 

#Path images of train
p1_train = train[train['Abs Position']=='P1' ]
p1_path_train = p1_train['Path Crop'].tolist() 
p2_train = train[train['Abs Position']=='P2' ]
p2_path_train = p2_train['Path Crop'].tolist() 
p3_train = train[train['Abs Position']=='P3' ]
p3_path_train = p3_train['Path Crop'].tolist() 
p4_train = train[train['Abs Position']=='P4' ]
p4_path_train = p4_train['Path Crop'].tolist() 
p5_train = train[train['Abs Position']=='P5' ]
p5_path_train = p5_train['Path Crop'].tolist() 
p6_train = train[train['Abs Position']=='P6' ]
p6_path_train = p6_train['Path Crop'].tolist() 
p7_train = train[train['Abs Position']=='P7' ]
p7_path_train = p7_train['Path Crop'].tolist() 
p8_train = train[train['Abs Position']=='P8' ]
p8_path_train = p8_train['Path Crop'].tolist()

# %%
# copy images each view to validation_view_dir

fnames = p1_path_val  
for fname in fnames:
    dst = os.path.join(validation_P1_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p2_path_val  
for fname in fnames:
    dst = os.path.join(validation_P2_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p3_path_val  
for fname in fnames:
    dst = os.path.join(validation_P3_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p4_path_val  
for fname in fnames:
    dst = os.path.join(validation_P4_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)  
    
fnames = p5_path_val  
for fname in fnames:
    dst = os.path.join(validation_P5_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p6_path_val  
for fname in fnames:
    dst = os.path.join(validation_P6_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p7_path_val  
for fname in fnames:
    dst = os.path.join(validation_P7_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p8_path_val  
for fname in fnames:
    dst = os.path.join(validation_P8_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# copy images each view to train_view_dir

    fnames = p1_path_train  
for fname in fnames:
    dst = os.path.join(train_P1_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p2_path_train  
for fname in fnames:
    dst = os.path.join(train_P2_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p3_path_train  
for fname in fnames:
    dst = os.path.join(train_P3_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p4_path_train  
for fname in fnames:
    dst = os.path.join(train_P4_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p5_path_train  
for fname in fnames:
    dst = os.path.join(train_P5_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p6_path_train  
for fname in fnames:
    dst = os.path.join(train_P6_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p7_path_train  
for fname in fnames:
    dst = os.path.join(train_P7_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p8_path_train  
for fname in fnames:
    dst = os.path.join(train_P8_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# %%
#Show number of  

print('total training images:', len(os.listdir(train_P1_dir))+len(os.listdir(train_P2_dir))+len(os.listdir(train_P3_dir))+len(os.listdir(train_P4_dir))
      +len(os.listdir(train_P5_dir))+len(os.listdir(train_P6_dir))+len(os.listdir(train_P7_dir))+len(os.listdir(train_P8_dir)))
print('total training P1 images:', len(os.listdir(train_P1_dir)))
print('total training P2 images:', len(os.listdir(train_P2_dir)))
print('total training P3 images:', len(os.listdir(train_P3_dir)))
print('total training P4 images:', len(os.listdir(train_P4_dir)))
print('total training P5 images:', len(os.listdir(train_P5_dir)))
print('total training P6 images:', len(os.listdir(train_P6_dir)))
print('total training P7 images:', len(os.listdir(train_P7_dir)))
print('total training P8 images:', len(os.listdir(train_P8_dir)),'\n')

print('total training images:', len(os.listdir(validation_P1_dir))+len(os.listdir(validation_P2_dir))+len(os.listdir(validation_P3_dir))
      +len(os.listdir(validation_P4_dir))+len(os.listdir(validation_P5_dir))+len(os.listdir(validation_P6_dir))+len(os.listdir(validation_P7_dir))
      +len(os.listdir(validation_P8_dir)))
print('total validation P1 images:', len(os.listdir(validation_P1_dir)))
print('total validation P2 images:', len(os.listdir(validation_P2_dir)))
print('total training P3 images:', len(os.listdir(validation_P3_dir)))
print('total training P4 images:', len(os.listdir(validation_P4_dir)))
print('total training P5 images:', len(os.listdir(validation_P5_dir)))
print('total training P6 images:', len(os.listdir(validation_P6_dir)))
print('total training P7 images:', len(os.listdir(validation_P7_dir)))
print('total training P8 images:', len(os.listdir(validation_P8_dir)))
# Out:
# total training images: 2863
# total training P1 images: 242
# total training P2 images: 239
# total training P3 images: 431
# total training P4 images: 480
# total training P5 images: 480
# total training P6 images: 301
# total training P7 images: 450
# total training P8 images: 240
#
# total training images: 125
# total validation P1 images: 10
# total validation P2 images: 10
# total training P3 images: 20
# total training P4 images: 21
# total training P5 images: 20
# total training P6 images: 14
# total training P7 images: 20
# total training P8 images: 10

# %% [markdown]
# # Trainning EfficientNet

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
import os
import glob
import shutil
import sys
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# ### Hyper parameters

# %%
#only have 2 label
batch_size = 50 #จำนวน data ที่ส่งไป Train ในแต่ละครั้ง จนครบจำนวนเต็ม x_train

width = 150 
height = 150 
input_shape = (height, width, 3) #ขนาด image enter

epochs = 500  #จำนวนรอบในการ Train
NUM_TRAIN = 2821# จำนวนภาพ Train
NUM_TEST = 125 #จำนวนภาพ Test
dropout_rate = 0.2 #คือการปิดบาง Node หรือเรียกว่าทำการ Drop Out ไป ซึ่งขึ้นกับการตั้งค่าว่าจะให้ลืมไปกี่เปอร์เซนต์ดี ช่วยในการแก้ปัญหา Overfitting

# %% [markdown]
# ### Import efficientnet and load the conv base model

# %%
# Options: EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3
# Higher the number, the more complex the model is.

from efficientnet import EfficientNetB0 as Net
from efficientnet import center_crop_and_resize, preprocess_input
# Out:
# Using TensorFlow backend.

# %%
# loading pretrained conv base model

conv_base = Net(weights='imagenet', include_top=False, input_shape=input_shape) # ไม่โหลด weights ของ layer สุดท้าย  include_top=False

# %% [markdown]
# ### Setting data augmentation

# %%
# data augmentation เพื่อลดโอกาสการเกิด overfitting

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
      rescale=1./255, # image input 0-255 --> 0-1 เปลี่ยนค่าสี
      rotation_range=40, # หมุนภาพในองศา
      width_shift_range=0.2, #เปลี่ยนความกว้าง
      height_shift_range=0.2, #ปลี่ยนความสูง
      shear_range=0.2, #ทำให้ภาพเบี้ยว
      zoom_range=0.2, #ซุม image มากสุด 20%
      horizontal_flip=True, #พลิกภาพแบบสุ่มตามแนวนอน
      fill_mode='nearest') 

# Note that the validation data should not be augmented!
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to target height and width.
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        # Since we use categorical_crossentropy loss, we need categorical labels
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        class_mode='categorical')
# Out:
# Found 2863 images belonging to 8 classes.
# Found 125 images belonging to 8 classes.

# %% [markdown]
# ### Show architecture model

# %%
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalMaxPooling2D(name="gap"))
# model.add(layers.Flatten(name="flatten"))
if dropout_rate > 0:
    model.add(layers.Dropout(dropout_rate, name="dropout_out"))
# model.add(layers.Dense(256, activation='relu', name="fc1"))
model.add(layers.Dense(8, activation='softmax', name="fc_out"))        #class --> 8

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Model)      (None, 5, 5, 1280)        4049564
# _________________________________________________________________
# gap (GlobalMaxPooling2D)     (None, 1280)              0
# _________________________________________________________________
# dropout_out (Dropout)        (None, 1280)              0
# _________________________________________________________________
# fc_out (Dense)               (None, 8)                 10248
# =================================================================
# Total params: 4,059,812
# Trainable params: 4,017,796
# Non-trainable params: 42,016
# _________________________________________________________________

# %%
print('This is the number of trainable layers '
      'before freezing the conv base:', len(model.trainable_weights))

conv_base.trainable = False  # freeze เพื่อรักษา convolutional base's weight

print('This is the number of trainable layers '
      'after freezing the conv base:', len(model.trainable_weights))  #freez แล้วจะเหลือ max pool and dense
# Out:
# This is the number of trainable layers before freezing the conv base: 213
# This is the number of trainable layers after freezing the conv base: 2

# %% [markdown]
# ### Training

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=2e-5),
              metrics=['acc'])

#history คือตัวแปรที่จะทำการเก็บประวัติการ Train Model ของเรา
#คำสั่ง Train
history = model.fit_generator(
      train_generator,#โหลดdataเข้ามา
      steps_per_epoch= NUM_TRAIN //batch_size,
      epochs=epochs,
      validation_data=validation_generator, #validation_data=(x_valid, y_valid): ใส่ data ที่เราแยกไว้เพื่อดูผล Model ว่าเกิด Overfitting เริ่มที่จุดใด
      validation_steps= NUM_TEST //batch_size,
      verbose=1, #โชว์ผลลัพธ์ 0:ปิด
      use_multiprocessing=True, #ใช้ GPU หลายตัว
      workers=1) #ทำพร้อมกันที่ละ 4 ตัว
# Out:
# Epoch 1/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 3.4937 - acc: 0.1180WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 533ms/step - loss: 3.4937 - acc: 0.1180 - val_loss: 2.8352 - val_acc: 0.1100
# Epoch 2/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 3.1768 - acc: 0.1292WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 524ms/step - loss: 3.1768 - acc: 0.1292 - val_loss: 2.5275 - val_acc: 0.1900
# Epoch 3/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 3.1023 - acc: 0.1459WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 528ms/step - loss: 3.1023 - acc: 0.1459 - val_loss: 2.4997 - val_acc: 0.1700
# Epoch 4/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 3.0746 - acc: 0.1288WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 531ms/step - loss: 3.0746 - acc: 0.1288 - val_loss: 2.4566 - val_acc: 0.1600
# Epoch 5/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 3.1304 - acc: 0.1267WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 527ms/step - loss: 3.1304 - acc: 0.1267 - val_loss: 2.2952 - val_acc: 0.1700
# Epoch 6/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.9946 - acc: 0.1401WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 524ms/step - loss: 2.9946 - acc: 0.1401 - val_loss: 2.3412 - val_acc: 0.1500
# Epoch 7/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.9544 - acc: 0.1498WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 520ms/step - loss: 2.9544 - acc: 0.1498 - val_loss: 2.2732 - val_acc: 0.1500
# Epoch 8/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.9187 - acc: 0.1473WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 521ms/step - loss: 2.9187 - acc: 0.1473 - val_loss: 2.1682 - val_acc: 0.2000
# Epoch 9/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.9058 - acc: 0.1448WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 530ms/step - loss: 2.9058 - acc: 0.1448 - val_loss: 2.2226 - val_acc: 0.1800
# Epoch 10/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.8208 - acc: 0.1705WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 524ms/step - loss: 2.8208 - acc: 0.1705 - val_loss: 2.1929 - val_acc: 0.1600
# Epoch 11/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.8085 - acc: 0.1553WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 525ms/step - loss: 2.8085 - acc: 0.1553 - val_loss: 2.0245 - val_acc: 0.2700
# Epoch 12/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.8105 - acc: 0.1647WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 528ms/step - loss: 2.8105 - acc: 0.1647 - val_loss: 2.0672 - val_acc: 0.2500
# Epoch 13/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.7381 - acc: 0.1784WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 527ms/step - loss: 2.7381 - acc: 0.1784 - val_loss: 2.0561 - val_acc: 0.2400
# Epoch 14/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 2.7274 - acc: 0.1741WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 521ms/step - loss:
500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4568 - acc: 0.4781WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 518ms/step - loss: 1.4568 - acc: 0.4781 - val_loss: 1.1716 - val_acc: 0.6000
# Epoch 269/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4925 - acc: 0.4698WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 523ms/step - loss: 1.4925 - acc: 0.4698 - val_loss: 1.1820 - val_acc: 0.6000
# Epoch 270/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4969 - acc: 0.4748WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 526ms/step - loss: 1.4969 - acc: 0.4748 - val_loss: 1.1663 - val_acc: 0.6200
# Epoch 271/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4597 - acc: 0.4716WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 527ms/step - loss: 1.4597 - acc: 0.4716 - val_loss: 1.0368 - val_acc: 0.6500
# Epoch 272/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4601 - acc: 0.4777WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 522ms/step - loss: 1.4601 - acc: 0.4777 - val_loss: 1.1370 - val_acc: 0.6400
# Epoch 273/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4948 - acc: 0.4633WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 516ms/step - loss: 1.4948 - acc: 0.4633 - val_loss: 1.1548 - val_acc: 0.6100
# Epoch 274/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4505 - acc: 0.4872WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 516ms/step - loss: 1.4505 - acc: 0.4872 - val_loss: 1.1878 - val_acc: 0.6000
# Epoch 275/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4521 - acc: 0.4879WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 515ms/step - loss: 1.4521 - acc: 0.4879 - val_loss: 1.1289 - val_acc: 0.5900
# Epoch 276/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4660 - acc: 0.4748WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 515ms/step - loss: 1.4660 - acc: 0.4748 - val_loss: 1.1494 - val_acc: 0.6100
# Epoch 277/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4813 - acc: 0.4759WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 29s 525ms/step - loss: 1.4813 - acc: 0.4759 - val_loss: 1.0966 - val_acc: 0.6300
# Epoch 278/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.5089 - acc: 0.4647WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 528ms/step - loss: 1.5089 - acc: 0.4647 - val_loss: 1.0793 - val_acc: 0.6200
# Epoch 279/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4428 - acc: 0.4738WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 529ms/step - loss: 1.4428 - acc: 0.4738 - val_loss: 1.0856 - val_acc: 0.6700
# Epoch 280/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - ETA: 0s - loss: 1.4703 - acc: 0.4817WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 56/56 [==============================] - 30s 527ms/step - loss: 1.4703 - acc: 0.4817 - val_loss: 1.0750 - val_acc: 0.6300
# Epoch 281/500
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 48/56 [========================>.....] - ETA: 4s - loss: 1.4685 - acc: 0.4812

# %%
import sys
sys.path.append('/media/tohn/SSD/Efficient_USAI/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})
# Out:
# Using TensorFlow backend.

# %%
# !ls
# Out:
# data	      __init__.py				  misc
# dog_vs_cat    kagglecatsanddogs_3367a.zip		  models
# efficientnet  Keras_efficientnet_transfer_learning.ipynb  README.md
# examples      MANIFEST.in				  setup.py

# %%
# import tensorflow as tf
# from tensorflow import keras
# tf.keras.models.load_model(
#     './models/Abs_b0_c11_250.h5', custom_objects=None, compile=True)

# %%
# from tensorflow import keras
# model = keras.models.load_model('/models/Abs_b0_c11_250.h5')

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/Efficient_USAI/content/efficientnet_keras_transfer_learning/models/Abs_b0_c11_250.h5")

# %% [markdown]
# ### Plot training performance

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_x = range(len(acc))

plt.plot(epochs_x, acc, 'bo', label='Training acc')
plt.plot(epochs_x, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs_x, loss, 'bo', label='Training loss')
plt.plot(epochs_x, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Fine tuning last several layers.
# ### The steps for fine-tuning a network are as follow:
#
# 1) Add your custom network on top of an already trained base network.
#
# 2) Freeze the base network.
#
# 3) Train the part you added.
#
# 4) Unfreeze some layers in the base network.
#
# 5) Jointly train both these layers and the part you added.
#
# ทำไปแล้ว 3 ขั้นตอนเพื่อที่จะหาว่า layers ใดควรที่จะ unfreeze

# %%
#plot the Keras model เพื่อหา  layers ที่จะ unfreeze

from tensorflow.keras.utils import plot_model
plot_model(conv_base, to_file='conv_base.png', show_shapes=True)
from IPython.display import Image
Image(filename='conv_base.png')

# %% [markdown]
# # Test predict

# %%
import sys
sys.path.append('/media/tohn/SSD/Efficient_USAI/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})
# Out:
# Using TensorFlow backend.

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/Efficient_USAI/content/efficientnet_keras_transfer_learning/models/Abs_b0_c11_250.h5")

# %%
p1_img = '/media/tohn/HDD/VISION_dataset/USAI/Prelim. Imgs/P1/Test/cropped2/P1_Case_001.jpg'
Image(filename=p1_img)

# %%
from tensorflow.keras.preprocessing import image

def predict_image(img_path):
    # Read the image and resize it
    img = image.load_img(img_path, target_size=(height, width))
    # Convert it to a Numpy array with target shape.
    x = image.img_to_array(img)
    # Reshape
    x = x.reshape((1,) + x.shape)
    x /= 255.
    result = model.predict([x])[0][0]
#     if result > 0.5:
#         animal = "cat"
#     else:
#         animal = "dog"
#         result = 1 - result
    return result

# print(predict_image(cat_img))
# print(predict_image(dog_img))

# %%
from tensorflow.keras.preprocessing import image
import pandas as pd
val = df1[df1['Case'].between(1, 10)]

# %%
n = 8
avgDists = result
idxs = avgDists.argsort()[::-1][:n]
idxs

# %%
classe =['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8']
results = list()

for i in classe:
    img_path =val[val['Abs Position']==i]['Path Crop'].tolist()
    for j in img_path:
        img = image.load_img(j, target_size=(height, width))
            # Convert it to a Numpy array with target shape.
        x = image.img_to_array(img)
            # Reshape
        x = x.reshape((1,) + x.shape)
        x /= 255.
        result = model.predict([x])[0]
        n = 8
        avgDists = result
        idxs = avgDists.argsort()[::-1][:n] #sort max
        predlist,problist = list(), list()
        for m in idxs:
            pred =  classe[m]
            prob = result[m]
            predlist.append(pred)
            problist.append(prob)
        act_true = i
        prob_max = problist[0]
        pred_max = predlist[0]

        results.append({'2Actual':act_true,'3Predicted':pred_max, '4Class_prob':prob_max, '5moreprop':problist[0:3],'6morepred':predlist[0:3],'path':j})

# %%
resultss = pd.DataFrame(results)
resultss
# Out:
#     2Actual 3Predicted  4Class_prob                                5moreprop  \
# 0        P1         P1     0.356386       [0.3563857, 0.2739771, 0.13678615]
# 1        P1         P3     0.269952      [0.2699523, 0.20189531, 0.19319437]
# 2        P1         P4     0.329762     [0.32976183, 0.26811084, 0.19858593]
# 3        P1         P1     0.315073     [0.31507295, 0.27487153, 0.12730674]
# 4        P1         P1     0.293229      [0.2932293, 0.22504091, 0.21996896]
# 5        P1         P3     0.417549      [0.41754913, 0.23641561, 0.1591102]
# 6        P1         P1     0.647684     [0.64768434, 0.14672767, 0.08145659]
# 7        P1         P1     0.396347     [0.39634717, 0.19131464, 0.18396233]
# 8        P1         P2     0.282990       [0.28298974, 0.2722419, 0.2309729]
# 9        P1         P1     0.293701     [0.29370135, 0.23645163, 0.17449154]
# 10       P2         P2     0.458320     [0.45832035, 0.17752045, 0.14250763]
# 11       P2         P2     0.418260    [0.41826007, 0.21118596, 0.105080746]
# 12       P2         P1     0.397601    [0.39760146, 0.34114826, 0.095272936]
# 13       P2         P2     0.899786    [0.89978576, 0.03498238, 0.019375548]
# 14       P2         P3     0.266976     [0.26697618, 0.17552093, 0.15966402]
# 15       P2         P2     0.614041    [0.61404055, 0.21080334, 0.082133666]
# 16       P2         P2     0.470541      [0.4705411, 0.17396262, 0.15593262]
# 17       P2         P2     0.484013    [0.48401332, 0.22964007, 0.079420276]
# 18       P2         P2     0.429699      [0.4296989, 0.42076403, 0.06581621]
# 19       P2         P3     0.397181     [0.39718106, 0.29811558, 0.13099416]
# 20       P3         P4     0.807775    [0.80777544, 0.18077064, 0.006333128]
# 21       P3         P4     0.831849    [0.83184946, 0.13102038, 0.017178204]
# 22       P3         P8     0.931271    [0.9312709, 0.031253245, 0.025669629]
# 23       P3         P3     0.651104      [0.6511039, 0.15659261, 0.07116709]
# 24       P3         P8     0.521849     [0.5218489, 0.23642522, 0.076456465]
# 25       P3         P3     0.714740    [0.71473986, 0.22573957, 0.052333597]
# 26       P3         P3     0.765629     [0.7656289, 0.16098379, 0.027917102]
# 27       P3         P8     0.891053    [0.89105344, 0.08636548, 0.009601518]
# 28       P3         P8     0.767288      [0.7672877, 0.07785444, 0.07467663]
# 29       P3         P2     0.525307       [0.5253065, 0.15452571, 0.1108413]
# ..      ...        ...          ...                                      ...
# 95       P7         P7     0.429052     [0.42905194, 0.31362462, 0.13077548]
# 96       P7         P7     0.813749      [0.81374866, 0.0665988, 0.03609383]
# 97       P7         P7     0.672501      [0.6725008, 0.12810181, 0.06269093]
# 98       P7         P7     0.531245     [0.53124505, 0.19533454, 0.09873366]
# 99       P7         P7     0.912436      [0.912436, 0.055534884, 0.01369916]
# 100      P7         P7     0.672723     [0.6727231, 0.18893191, 0.051908486]
# 101      P7         P3     0.455658      [0.45565814, 0.2291941, 0.10331773]
# 102      P7         P7     0.965638  [0.96563804, 0.022995317, 0.0068654222]
# 103      P7         P7     0.305879      [0.3058794, 0.19303626, 0.18252137]
# 104      P7         P7     0.726040     [0.7260402, 0.22906353, 0.020924287]
# 105      P7         P7     0.660696     [0.66069597, 0.08374155, 0.07696563]
# 106      P7         P5     0.517205     [0.5172053, 0.28931507, 0.051526506]
# 107      P7         P7     0.965286   [0.96528614, 0.021028098, 0.009136117]
# 108      P7         P8     0.462437     [0.46243724, 0.4456388, 0.039471637]
# 109      P7         P7     0.881829    [0.8818289, 0.108119115, 0.005299682]
# 110      P7         P7     0.768608      [0.7686079, 0.07308626, 0.05541196]
# 111      P7         P5     0.512460       [0.5124595, 0.4118113, 0.02767552]
# 112      P7         P7     0.649634     [0.64963365, 0.17068686, 0.07463156]
# 113      P7         P7     0.290780      [0.29077998, 0.27412587, 0.2547008]
# 114      P7         P7     0.470143     [0.47014293, 0.21079478, 0.15480976]
# 115      P8         P8     0.914939   [0.91493857, 0.029053252, 0.024604743]
# 116      P8         P8     0.408968     [0.40896827, 0.19590844, 0.13397256]
# 117      P8         P8     0.928329   [0.92832947, 0.025968764, 0.021816086]
# 118      P8         P8     0.626275      [0.6262751, 0.2592041, 0.064747706]
# 119      P8         P3     0.568136     [0.56813645, 0.2412934, 0.064470544]
# 120      P8         P3     0.667814       [0.6678136, 0.2045419, 0.06710225]
# 121      P8         P8     0.686743     [0.68674254, 0.21615586, 0.04709422]
# 122      P8         P8     0.977015  [0.97701526, 0.014387691, 0.0032765586]
# 123      P8         P8     0.877544   [0.87754416, 0.093007624, 0.012390365]
# 124      P8         P8     0.882555    [0.8825551, 0.10275683, 0.0059304405]
#
#         6morepred                                               path
# 0    [P1, P2, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1    [P3, P1, P8]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2    [P4, P1, P6]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3    [P1, P7, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4    [P1, P3, P7]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5    [P3, P2, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6    [P1, P3, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7    [P1, P6, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8    [P2, P1, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9    [P1, P4, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10   [P2, P3, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11   [P2, P6, P7]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12   [P1, P6, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13   [P2, P1, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14   [P3, P2, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15   [P2, P1, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16   [P2, P3, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17   [P2, P3, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18   [P2, P1, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19   [P3, P2, P6]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20   [P4, P3, P6]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21   [P4, P3, P5]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22   [P8, P2, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23   [P3, P4, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24   [P8, P3, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25   [P3, P4, P6]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26   [P3, P6, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27   [P8, P3, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28   [P8, P2, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29   [P2, P3, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ..            ...                                                ...
# 95   [P7, P3, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 96   [P7, P2, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 97   [P7, P1, P5]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 98   [P7, P5, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 99   [P7, P5, P8]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 100  [P7, P5, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 101  [P3, P8, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 102  [P7, P8, P5]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 103  [P7, P1, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 104  [P7, P8, P5]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 105  [P7, P5, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 106  [P5, P7, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 107  [P7, P5, P8]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 108  [P8, P7, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 109  [P7, P8, P5]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 110  [P7, P5, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 111  [P5, P7, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 112  [P7, P8, P5]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 113  [P7, P3, P8]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 114  [P7, P2, P5]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 115  [P8, P3, P7]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 116  [P8, P3, P6]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 117  [P8, P7, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 118  [P8, P3, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 119  [P3, P8, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 120  [P3, P8, P4]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 121  [P8, P3, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 122  [P8, P3, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 123  [P8, P3, P7]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 124  [P8, P7, P3]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
# [125 rows x 6 columns]

# %%
os.chdir( '/home/yupaporn/codes/USAI/')
resultss.to_csv('result1_250.csv')

# %%
# classe =['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8']
# results = list()
# # act, prob, top_pred, top_prob = list(),list(),list(),list()
# for i in classe:
#     img_path =val[val['Abs Position']==i]['Path Crop'].tolist()
#     for j in img_path:
#         img = image.load_img(j, target_size=(height, width))
#             # Convert it to a Numpy array with target shape.
#         x = image.img_to_array(img)
#             # Reshape
#         x = x.reshape((1,) + x.shape)
#         x /= 255.
#         result = model.predict([x])[0]
#         n = 8
#         avgDists = result
#         idxs = avgDists.argsort()[::-1][:n] #sort max
#         predlist,problist = list(), list()
#         for m in idxs:
#             pred =  classe[m]
#             prob = result[m]
#             predlist.append(pred)
#             problist.append(prob)
#         act_true = i
#         prob_max = problist[0]
#         pred_max = predlist[0]
# #         toppred= predlist[0:3]
# #         topprob  = result[0:3]
# #         #Keep 
# #         act.append(act_true)
# #         prob.append(prob_max) 
# #         top_pred.append(pred_max)
# #         top_prob.append(topprob)
#         results.append({'2Actual':act_true,'3Predicted':pred_max, '4Class_prob':prob_max, '5moreprop':problist[0:3],'6morepred':predlist[0:3],'path':j})

# %%
# #class Label
# os.chdir('/media/tohn/SSD/Efficient_USAI/content/efficientnet_keras_transfer_learning/data/views/train/')
# from glob import glob
# # class_names = glob("*") # Reads all the folders in which images are present
# class_names = sorted(glob("*")) # Sorting them
# name_id_map = dict(zip(class_names, range(len(class_names))))

# %%
# n = 8
# avgDists = result
# idxs = avgDists.argsort()[::-1][:n]
# idxs
# labellist,predlist = list(),list()
# # top_prob,top_pred = list(),list()

# %%
# # Directory with our training cat pictures
# validation_P1_dir = os.path.join(validation_dir, 'P1')
# os.makedirs(validation_P1_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P2_dir = os.path.join(validation_dir, 'P2')
# os.makedirs(validation_P2_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P31_dir = os.path.join(validation_dir, 'P31')
# os.makedirs(validation_P31_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P32_dir = os.path.join(validation_dir, 'P32')
# os.makedirs(validation_P32_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P41_dir = os.path.join(validation_dir, 'P41')
# os.makedirs(validation_P41_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P42_dir = os.path.join(validation_dir, 'P42')
# os.makedirs(validation_P42_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P51_dir = os.path.join(validation_dir, 'P51')
# os.makedirs(validation_P51_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P52_dir = os.path.join(validation_dir, 'P52')
# os.makedirs(validation_P52_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P6_dir = os.path.join(validation_dir, 'P6')
# os.makedirs(validation_P6_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P62_dir = os.path.join(validation_dir, 'P62')
# os.makedirs(validation_P62_dir, exist_ok=True)
# validation_P71_dir = os.path.join(validation_dir, 'P71')
# os.makedirs(validation_P71_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P72_dir = os.path.join(validation_dir, 'P72')
# os.makedirs(validation_P72_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P8_dir = os.path.join(validation_dir, 'P8')
# os.makedirs(validation_P8_dir, exist_ok=True)

# # Directory with our training cat pictures
# train_P1_dir = os.path.join(train_dir, 'P1')
# os.makedirs(train_P1_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P2_dir = os.path.join(train_dir, 'P2')
# os.makedirs(train_P2_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P31_dir = os.path.join(train_dir, 'P31')
# os.makedirs(train_P31_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P32_dir = os.path.join(train_dir, 'P32')
# os.makedirs(train_P32_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P41_dir = os.path.join(train_dir, 'P41')
# os.makedirs(train_P41_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P42_dir = os.path.join(train_dir, 'P42')
# os.makedirs(train_P42_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P51_dir = os.path.join(train_dir, 'P51')
# os.makedirs(train_P51_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P52_dir = os.path.join(train_dir, 'P52')
# os.makedirs(train_P52_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P6_dir = os.path.join(train_dir, 'P6')
# os.makedirs(train_P6_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P62_dir = os.path.join(train_dir, 'P62')
# os.makedirs(train_P62_dir, exist_ok=True)
# train_P71_dir = os.path.join(train_dir, 'P71')
# os.makedirs(train_P71_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P72_dir = os.path.join(train_dir, 'P72')
# os.makedirs(train_P72_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P8_dir = os.path.join(train_dir, 'P8')
# os.makedirs(train_P8_dir, exist_ok=True)
