# %%
import pandas as pd
df0 = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_350_.csv')
# df01 = df0[(df0['Path Crop']!='None' )&(df0['Path Crop']!='Nan')]
# a = df01[df01['Case'].between(1, 10)]
# a = a[a['Abs Position']!='P8']
# print(a.shape)
# print('Normal: ',a[a['Class']=='Normal'].shape)
# print('Abnormal: ',a[a['Class']=='Abnormal'].shape)
df0
# Out:
#       Unnamed: 0  Case Abs Position Sub Position     Class Sub_class  \
# 0              0    15           P3          P31  Abnormal      AB01
# 1              1    42           P5          P52  Abnormal      AB01
# 2              2    22           P2           P2  Abnormal      AB01
# 3              3    25           P4          P41  Abnormal      AB01
# 4              4    40           P1           P1  Abnormal      AB01
# 5              5    13           P4          P42  Abnormal      AB01
# 6              6    27           P2           P2  Abnormal      AB01
# 7              7    86           P3          P31  Abnormal      AB01
# 8              8    45           P5          P52  Abnormal      AB01
# 9              9    20           P3          P31  Abnormal      AB01
# 10            10    37           P1           P1  Abnormal      AB01
# 11            11    32           P2           P2  Abnormal      AB01
# 12            12    64           P3          P31  Abnormal      AB01
# ...

# %%
mum = df0['Abs Position'].tolist()

# %%
nitviews = list()
for i in range(0,len(mum)):
    if mum[i]=='P1':
        view = 'FP-A'
        nitviews.append({'Views':view})
    elif mum[i]=='P2':
        view = 'FP-A'
        nitviews.append({'Views':view})
    elif mum[i]=='P3':
        view = 'FP-B'
        nitviews.append({'Views':view})
    elif mum[i]=='P4':
        view = 'FP-B'
        nitviews.append({'Views':view})
    elif mum[i]=='P5':
        view = 'FP-C'
        nitviews.append({'Views':view})
    elif mum[i]=='P6':
        view = 'FP-C'
        nitviews.append({'Views':view})
    elif mum[i]=='P7':
        view = 'FP-D'
        nitviews.append({'Views':view})
    elif mum[i]=='P8':
        view = 'None'
        nitviews.append({'Views':view})

# %%
Nm1_10df = pd.DataFrame(nitviews)
Nm1_10df
# Out:
#      Views
# 0     FP-B
# 1     FP-C
# 2     FP-A
# 3     FP-B
# 4     FP-A
# 5     FP-B
# 6     FP-A
# 7     FP-B
# 8     FP-C
# 9     FP-B
# 10    FP-A
# 11    FP-A
# 12    FP-B
# 13    FP-A
# 14    FP-A
# 15    FP-B
# 16    FP-A
# 17    FP-B
# 18    FP-B
# 19    FP-C
# 20    FP-C
# 21    FP-B
# 22    FP-B
# 23    FP-A
# 24    FP-B
# 25    FP-C
# 26    FP-C
# 27    FP-C
# 28    FP-B
# 29    FP-B
# ...    ...
# 6089  None
# 6090  None
# 6091  None
# 6092  None
# 6093  None
# 6094  None
# 6095  None
# 6096  None
# 6097  None
# 6098  None
# 6099  None
# 6100  None
# 6101  None
# 6102  None
# 6103  None
# 6104  None
# 6105  None
# 6106  None
# 6107  None
# 6108  None
# 6109  None
# 6110  None
# 6111  None
# 6112  None
# 6113  None
# 6114  None
# 6115  None
# 6116  None
# 6117  None
# 6118  None
#
# [6119 rows x 1 columns]

# %%
dfnew = df0.join(Nm1_10df)
dfnew
# Out:
#       Unnamed: 0  Case Abs Position Sub Position     Class Sub_class  \
# 0              0    15           P3          P31  Abnormal      AB01
# 1              1    42           P5          P52  Abnormal      AB01
# 2              2    22           P2           P2  Abnormal      AB01
# 3              3    25           P4          P41  Abnormal      AB01
# 4              4    40           P1           P1  Abnormal      AB01
# 5              5    13           P4          P42  Abnormal      AB01
# 6              6    27           P2           P2  Abnormal      AB01
# 7              7    86           P3          P31  Abnormal      AB01
# 8              8    45           P5          P52  Abnormal      AB01
# 9              9    20           P3          P31  Abnormal      AB01
# 10            10    37           P1           P1  Abnormal      AB01
# 11            11    32           P2           P2  Abnormal      AB01
# 12            12    64           P3          P31  Abnormal      AB01
# ...

# %%
# os.chdir( '/home/yupaporn/codes/USAI/')
# dfnew.to_csv('detail1_350_new.csv')

# %% [markdown]
# # Train

# %%
import pandas as pd
import numpy as np
import shutil
df = pd.read_csv (r'/home/yupaporn/EfficientNet_USAI/final_training_table.csv')
# df =df[df['Path Crop'] != 'None']
# df.dropna()
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0           2053          2053    40           P3          P31    Normal
# 1           3682          3682   194           P3          P31    Normal
# 2           2000          2000    59           P3          P31    Normal
# 3           3090          3090   105           P3          P31    Normal
# 4           2001          2001    14           P3          P31    Normal
# 5           2594          2594    93           P3          P31    Normal
# 6           2586          2586    84           P3          P31    Normal
# 7           2031          2031    35           P3          P31    Normal
# 8           3667          3667   173           P3          P31    Normal
# 9           3659          3659   180           P3          P31    Normal
# 10          2593          2593    92           P3          P31    Normal
# 11          3696          3696   176           P3          P31    Normal
# ...

# %%
mum = df['Abs Position'].tolist()
nitviews = list()
for i in range(0,len(mum)):
    if mum[i]=='P1':
        view = 'FP-A'
        nitviews.append({'Views':view})
    elif mum[i]=='P2':
        view = 'FP-A'
        nitviews.append({'Views':view})
    elif mum[i]=='P3':
        view = 'FP-B'
        nitviews.append({'Views':view})
    elif mum[i]=='P4':
        view = 'FP-B'
        nitviews.append({'Views':view})
    elif mum[i]=='P5':
        view = 'FP-C'
        nitviews.append({'Views':view})
    elif mum[i]=='P6':
        view = 'FP-C'
        nitviews.append({'Views':view})
    elif mum[i]=='P7':
        view = 'FP-D'
        nitviews.append({'Views':view})
    elif mum[i]=='P8':
        view = 'None'
        nitviews.append({'Views':view})
Nm1_10df = pd.DataFrame(nitviews)
dfnew = df.join(Nm1_10df)
dfnew
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0           2053          2053    40           P3          P31    Normal
# 1           3682          3682   194           P3          P31    Normal
# 2           2000          2000    59           P3          P31    Normal
# 3           3090          3090   105           P3          P31    Normal
# 4           2001          2001    14           P3          P31    Normal
# 5           2594          2594    93           P3          P31    Normal
# 6           2586          2586    84           P3          P31    Normal
# 7           2031          2031    35           P3          P31    Normal
# 8           3667          3667   173           P3          P31    Normal
# 9           3659          3659   180           P3          P31    Normal
# 10          2593          2593    92           P3          P31    Normal
# 11          3696          3696   176           P3          P31    Normal
# ...

# %%
import os
# os.path.abspath('/media/tohn/SSD/Efficient_USAI')
os.chdir('/media/tohn/SSD/ImageForTrainTest/')
# !ls
# Out:
# train  train.csv  train_Sub  validation  validation.csv

# %%
# print(set(df['Case']))

# %%
# os.path.basename('/media/tohn/HDD/VISION_dataset/USAI/croppedPrelim/P3/P3_Case_040-1.jpg')

# %%
df = dfnew

# %%
import os

# %%
dic = {"filename": []}
case = list()

path_train = df['Path Crop'].tolist() 
#Train
train_Nor_dir = '/media/tohn/SSD/ImageForTrainTest/train'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    dic["filename"].append(a)
    shutil.copyfile(fname, dst)

# %%
dics = pd.DataFrame(dic)
len(dics)
# Out:
# 2508

# %%
dics = pd.DataFrame(dic)
table = df.join(dics)
table = table.drop(columns=['Unnamed: 0','Unnamed: 0.1',  'Path Full'])
table
# Out:
#       Case Abs Position Sub Position     Class Sub_class  \
# 0       40           P3          P31    Normal    Normal
# 1      194           P3          P31    Normal    Normal
# 2       59           P3          P31    Normal    Normal
# 3      105           P3          P31    Normal    Normal
# 4       14           P3          P31    Normal    Normal
# 5       93           P3          P31    Normal    Normal
# 6       84           P3          P31    Normal    Normal
# 7       35           P3          P31    Normal    Normal
# 8      173           P3          P31    Normal    Normal
# 9      180           P3          P31    Normal    Normal
# 10      92           P3          P31    Normal    Normal
# 11     176           P3          P31    Normal    Normal
# 12      18           P3          P31    Normal    Normal
# 13      58           P3          P31    Normal    Normal
# 14      26           P3          P31    Normal    Normal
# ...

# %%
# print(len(set(table['filename'])))

# %%
# name = table['filename'].tolist()
# m = table.groupby('filename').count()
# m = m['Case'].tolist()
# for i in range(0,len(m)):
#     if m[i] !=1 :
#         path = name[i]
#         print(path)

# %%
# os.chdir( '/media/tohn/SSD/ImageForTrainTest/')
# table.to_csv('train.csv')

# %% [markdown]
# # Validation

# %%
import pandas as pd
df0 = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_350_new.csv')
df01 = df0[(df0['Path Crop']!='None' )&(df0['Path Crop']!='Nan')]
a = df01[df01['Case'].between(1, 10)]
a = a[a['Abs Position']!='P8']
print(a.shape)
print('Normal: ',a[a['Class']=='Normal'].shape)
print('Abnormal: ',a[a['Class']=='Abnormal'].shape)
# Out:
# (405, 10)
# Normal:  (115, 10)
# Abnormal:  (290, 10)

# %%
dic = {"filename": []}

path_train = a['Path Crop'].tolist() 
#validation
train_Nor_dir = '/media/tohn/SSD/ImageForTrainTest/validation'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    m = dst.split('/')[-1]
    dic["filename"].append(m)
    shutil.copyfile(fname, dst)

# %%
a = a.reset_index(drop=True)
dics = pd.DataFrame(dic)
table_a = a.join(dics)
table_a = table_a.drop(columns=['Unnamed: 0', 'Path Full'])
table_a
# Out:
#      Unnamed: 0.1  Case Abs Position Sub Position     Class Sub_class  \
# 0              13     3           P2           P2  Abnormal      AB01
# 1              15     7           P3          P31  Abnormal      AB01
# 2              16     5           P2           P2  Abnormal      AB01
# 3              26     9           P5          P51  Abnormal      AB01
# 4              29     3           P3          P31  Abnormal      AB01
# 5              33     8           P4          P42  Abnormal      AB01
# 6              34     9           P3          P31  Abnormal      AB01
# 7              43     2           P2           P2  Abnormal      AB01
# 8              49     7           P4          P42  Abnormal      AB01
# 9              59     9           P5          P52  Abnormal      AB01
# 10             82     1           P3          P31  Abnormal      AB01
# 11             84     2           P4          P41  Abnormal      AB01
# ...

# %%
print(len(set(table_a['filename'])))
# Out:
# 405

# %%
# os.chdir( '/media/tohn/SSD/ImageForTrainTest/')
# table_a.to_csv('validation.csv')

# %% [markdown]
# # Train_Subviews

# %%
import pandas as pd
df0 = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_350_new.csv')
# df01 = df0[(df0['Path Crop']!='None' )&(df0['Path Crop']!='Nan')]
print(df0.shape)
print('Normal: ',df0[df0['Class']=='Normal'].shape)
print('Abnormal: ',df0[df0['Class']=='Abnormal'].shape)
# Out:
# (6119, 10)
# Normal:  (4350, 10)
# Abnormal:  (1769, 10)

# %%
import pandas as pd
df0 = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_350_new.csv')
df01= df0[(df0['Path Crop']!='None' )&(df0['Path Crop']!='Nan')]
a0 = df01[df01['Case'].between(11, 250)]
a0 = a0[a0['Abs Position']!='P8']

print('General:',df01.shape)
print('Selected:',a0.shape)
print('Normal: ',a0[a0['Class']=='Normal'].shape)
print('Abnormal: ',a0[a0['Class']=='Abnormal'].shape)
# Out:
# General: (5996, 10)
# Selected: (4117, 10)
# Normal:  (2656, 10)
# Abnormal:  (1461, 10)

# %%
a = a0

# %%
dic = {"filename": []}

path_train = a['Path Crop'].tolist() 
#validation
train_Nor_dir = '/media/tohn/SSD/ImageForTrainTest/train_Sub'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    m = dst.split('/')[-1]
    dic["filename"].append(m)
    shutil.copyfile(fname, dst)

# %%
a = a.reset_index(drop=True)
dics = pd.DataFrame(dic)
table_a = a.join(dics)
table_a = table_a.drop(columns=['Unnamed: 0', 'Path Full'])
table_a
# Out:
#       Unnamed: 0.1  Case Abs Position Sub Position     Class Sub_class  \
# 0                0    15           P3          P31  Abnormal      AB01
# 1                1    42           P5          P52  Abnormal      AB01
# 2                2    22           P2           P2  Abnormal      AB01
# 3                3    25           P4          P41  Abnormal      AB01
# 4                4    40           P1           P1  Abnormal      AB01
# 5                5    13           P4          P42  Abnormal      AB01
# 6                6    27           P2           P2  Abnormal      AB01
# 7                7    86           P3          P31  Abnormal      AB01
# 8                8    45           P5          P52  Abnormal      AB01
# 9                9    20           P3          P31  Abnormal      AB01
# 10              10    37           P1           P1  Abnormal      AB01
# 11              11    32           P2           P2  Abnormal      AB01
# ...

# %%
# os.chdir( '/media/tohn/SSD/ImageForTrainTest/')
# table_a.to_csv('train_Sub.csv')

# %% [markdown]
# # Checking

# %%
df = pd.read_csv (r'/media/tohn/SSD/ImageForTrainTest/train_Sub.csv')
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0             0    15           P3          P31  Abnormal
# 1              1             1    42           P5          P52  Abnormal
# 2              2             2    22           P2           P2  Abnormal
# 3              3             3    25           P4          P41  Abnormal
# 4              4             4    40           P1           P1  Abnormal
# 5              5             5    13           P4          P42  Abnormal
# 6              6             6    27           P2           P2  Abnormal
# 7              7             7    86           P3          P31  Abnormal
# 8              8             8    45           P5          P52  Abnormal
# 9              9             9    20           P3          P31  Abnormal
# 10            10            10    37           P1           P1  Abnormal
# 11            11            11    32           P2           P2  Abnormal
# ...

# %%
nor = df[df['Class']=='Normal']
print(nor.shape)
print(len(set(nor['filename'])))
# print(set(nor['path']))
# Out:
# (1254, 9)
# 1254

# %%
name = nor['filename'].tolist()
m = nor.groupby('filename').count()
m = m['Case'].tolist()
for i in range(0,len(m)):
    if m[i] >1 :
        path = name[i]
        print(path)

# %%
m = m['filename'].tolist()
for i in range(0,len(m)):
    if m[i] >1 :
        path = name[i]
        print(path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-3e21c3121858> in <module>
# ----> 1 m = m['filename'].tolist()
#       2 for i in range(0,len(m)):
#       3     if m[i] >1 :
#       4         path = name[i]
#       5         print(path)
#
# TypeError: list indices must be integers or slices, not str

# %%
ll=os.listdir('/media/tohn/SSD/ImageForTrainTest/train/')

# %%
name = df['path'].tolist()
len(name)
# Out:
# 2508

# %%
len(set(ll))
# Out:
# 2508

# %%
print (set(ll).difference(set(name)))
# Out:
# {'P6C150.jpgcp.jpg', 'P2C150.jpgcp.jpg', 'P4.1C150.jpgcp.jpg', 'P1C150.jpgcp.jpg', 'P5.1C150.jpgcp.jpg', 'P3.1C150.jpgcp.jpg'}

# %%
name = nor['Path Crop'].tolist()
a = name[0]
a
# Out:
# '/media/tohn/HDD/VISION_dataset/USAI/croppedPrelim/P3/P3_Case_040-1.jpg'

# %%
os.path.basename('/media/tohn/HDD/VISION_dataset/USAI/croppedPrelim/P3/P3_Case_040-1.jpg')
# Out:
# 'P3_Case_040-1.jpg'

# %%
nor.groupby(['path']).count()
df.groupby('a')['b'].apply(list)
# Out:
#                    Unnamed: 0  Case  Abs Position  Sub Position  Class  \
# path
# P1C061.jpg                  1     1             1             1      1
# P1C062.jpg                  1     1             1             1      1
# P1C063.jpg                  1     1             1             1      1
# P1C063_1.jpg                1     1             1             1      1
# P1C064.jpg                  1     1             1             1      1
# P1C066.jpg                  1     1             1             1      1
# P1C067.jpg                  1     1             1             1      1
# P1C068.jpg                  1     1             1             1      1
# P1C069.jpg                  1     1             1             1      1
# P1C070.jpg                  1     1             1             1      1
# P1C071.jpg                  1     1             1             1      1
# P1C072.jpg                  1     1             1             1      1
# ...

# %%
len(set(df['path']))
# Out:
# 2502

# %%
val = pd.read_csv (r'/media/tohn/SSD/ImageForTrainTest/validation.csv')
val
# Out:
#      Unnamed: 0  Case Abs Position Sub Position     Class Sub_class  \
# 0             0     3           P2           P2  Abnormal      AB01
# 1             1     7           P3          P31  Abnormal      AB01
# 2             2     5           P2           P2  Abnormal      AB01
# 3             3     9           P5          P51  Abnormal      AB01
# 4             4     3           P3          P31  Abnormal      AB01
# 5             5     8           P4          P42  Abnormal      AB01
# 6             6     9           P3          P31  Abnormal      AB01
# 7             7     2           P2           P2  Abnormal      AB01
# 8             8     7           P4          P42  Abnormal      AB01
# 9             9     9           P5          P52  Abnormal      AB01
# 10           10     1           P3          P31  Abnormal      AB01
# 11           11     2           P4          P41  Abnormal      AB01
# 12           12     3           P1           P1  Abnormal      AB01
# ...

# %%
len(val)
# Out:
# 405
