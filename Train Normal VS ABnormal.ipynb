# %% [markdown]
# # Load model

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
import os
import glob
import shutil
import sys
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from IPython.display import Image
from tensorflow.keras import callbacks

# %%
import os
# os.path.abspath('/media/tohn/SSD/Efficient_USAI')
os.chdir('/media/tohn/SSD/Nor_ABnor_Network')
# !ls
  #choose gpu on processing 
os.environ["CUDA_VISIBLE_DEVICES"]="1" # second gpu
# Out:
# content  my_logs

# %%
import os
# %cd content
if not os.path.isdir("efficientnet_keras_transfer_learning"):
  # !git clone https://github.com/Peckkie/efficientnet_keras_transfer_learning.git
# %cd efficientnet_keras_transfer_learning/
# Out:
# /media/tohn/SSD/Nor_ABnor_Network/content
# /media/tohn/SSD/Nor_ABnor_Network/content/efficientnet_keras_transfer_learning

# %%
import sys
sys.path.append('/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning/models/Sub_b0_c11_250_R2.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Model)      (None, 5, 5, 1280)        4049564
# _________________________________________________________________
# gap (GlobalMaxPooling2D)     (None, 1280)              0
# _________________________________________________________________
# dropout_out (Dropout)        (None, 1280)              0
# _________________________________________________________________
# fc_out (Dense)               (None, 13)                16653
# =================================================================
# Total params: 4,066,217
# Trainable params: 798,093
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %%
model.pop()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Model)      (None, 5, 5, 1280)        4049564
# _________________________________________________________________
# gap (GlobalMaxPooling2D)     (None, 1280)              0
# _________________________________________________________________
# dropout_out (Dropout)        (None, 1280)              0
# =================================================================
# Total params: 4,049,564
# Trainable params: 781,440
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %% [markdown]
# ### สร้าง Network ใหม่

# %%
model2 = models.Sequential()
model2.add(model)
model2.add(layers.Dense(1, activation='sigmoid', name="fc_out"))        #class --> 2
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 1280)              4049564
# _________________________________________________________________
# fc_out (Dense)               (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 782,721
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %% [markdown]
# ### จัดการ data

# %%
import pandas as pd
df = pd.read_csv (r'/home/yupaporn/EfficientNet_USAI/final_training_table.csv')
# df =df[df['Path Crop'] != 'None']
# df.dropna()
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0           2053          2053    40           P3          P31    Normal
# 1           3682          3682   194           P3          P31    Normal
# 2           2000          2000    59           P3          P31    Normal
# 3           3090          3090   105           P3          P31    Normal
# 4           2001          2001    14           P3          P31    Normal
# 5           2594          2594    93           P3          P31    Normal
# 6           2586          2586    84           P3          P31    Normal
# 7           2031          2031    35           P3          P31    Normal
# 8           3667          3667   173           P3          P31    Normal
# 9           3659          3659   180           P3          P31    Normal
# 10          2593          2593    92           P3          P31    Normal
# 11          3696          3696   176           P3          P31    Normal
# 12          2018          2018    18           P3          P31    Normal
# 13          2039          2039    58           P3          P31    Normal
# 14          2037          2037    26           P3          P31    Normal
# 15          3665          3665   162           P3          P31    Normal
# 16          2575          2575    72           P3          P31    Normal
# 17          2061          2061    49           P3          P31    Normal
# 18          2015          2015    19           P3          P31    Normal
# 19          2608          2608    86           P3          P31    Normal
# 20          3059          3059   138           P3          P31    Normal
# 21          3690          3690   182           P3          P31    Normal
# 22          3089          3089   112           P3          P31    Normal
# 23          2083          2083    16           P3          P31    Normal
# 24          3105          3105   113           P3          P31    Normal
# 25          2587          2587    70           P3          P31    Normal
# 26          3660          3660   177           P3          P31    Normal
# 27          2604          2604    90           P3          P31    Normal
# 28          3077          3077   131           P3          P31    Normal
# 29          2602          2602    68           P3          P31    Normal
# ...          ...           ...   ...          ...          ...       ...
# 2478        1746          1746    66           P7          P72  Abnormal
# 2479        1677          1677    58           P7          P72  Abnormal
# 2480        1752          1752    41           P7          P72  Abnormal
# 2481        1758          1758    39           P7          P72  Abnormal
# 2482        1686          1686    93           P7          P72  Abnormal
# 2483        1717          1717    67           P7          P72  Abnormal
# 2484        1736          1736    50           P7          P72  Abnormal
# 2485        1690          1690    69           P7          P72  Abnormal
# 2486        1727          1727    92           P7          P72  Abnormal
# 2487        1721          1721    47           P7          P72  Abnormal
# 2488        1701          1701    26           P7          P72  Abnormal
# 2489        1764          1764    83           P7          P72  Abnormal
# 2490        1766          1766    95           P7          P72  Abnormal
# 2491        1739          1739    15           P7          P72  Abnormal
# 2492        1743          1743    55           P7          P72  Abnormal
# 2493        1734          1734    53           P7          P72  Abnormal
# 2494        1740          1740    74           P7          P72  Abnormal
# 2495        1754          1754    33           P7          P72  Abnormal
# 2496        1728          1728    52           P7          P72  Abnormal
# 2497        1697          1697    40           P7          P72  Abnormal
# 2498        1765          1765    63           P7          P72  Abnormal
# 2499        1732          1732    45           P7          P72  Abnormal
# 2500        1712          1712    60           P7          P72  Abnormal
# 2501        1725          1725    31           P7          P72  Abnormal
# 2502        1716          1716    91           P7          P72  Abnormal
# 2503        1699          1699    51           P7          P72  Abnormal
# 2504        1709          1709    81           P7          P72  Abnormal
# 2505        1706          1706    94           P7          P72  Abnormal
# 2506        1708          1708    72           P7          P72  Abnormal
# 2507        1747          1747    85           P7          P72  Abnormal
#
#      Sub_class                                          Path Full  \
# 0       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 4       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 7       Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 9       Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 10      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 11      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 12      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 16      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 17      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 20      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 21      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 22      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 23      Normal  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 25      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 26      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 27      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 28      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 29      Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# ...        ...                                                ...
# 2478      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2479      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2480      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2481      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2482      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2483      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2484      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2485      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2486      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2487      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2488      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2489      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2490      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2491      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2492      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2493      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2494      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2495      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2496      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2497      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2498      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2499      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2500      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2501      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2502      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2503      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2504      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2505      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2506      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2507      AB11  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 1     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 3     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 4     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 5     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 7     /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 8     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 9     /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 10    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 11    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 12    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 13    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 14    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 15    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 16    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 17    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 18    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 19    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 20    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 21    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 22    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 23    /media/tohn/HDD/VISION_dataset/USAI/croppedPre...
# 24    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 25    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 26    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 27    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 28    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 29    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# ...                                                 ...
# 2478  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2479  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2480  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2481  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2482  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2483  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2484  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2485  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2486  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2487  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2488  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2489  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2490  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2491  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2492  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2493  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2494  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2495  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2496  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2497  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2498  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2499  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2500  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2501  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2502  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2503  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2504  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2505  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2506  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2507  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
# [2508 rows x 9 columns]

# %%
msk = np.random.rand(len(df)) < 0.9

# %%
test = df[~msk]
train= df[msk]

# %% [markdown]
# #### การเเบ่งข้อมูล train/validation/test sets

# %%
# The directory where we will
base_dir = './data/views'
os.makedirs(base_dir, exist_ok=True)

# Directories for our training,
# validation and test splits
train_dir = os.path.join(base_dir, 'train')
os.makedirs(train_dir, exist_ok=True)

validation_dir = os.path.join(base_dir, 'validation')
os.makedirs(train_dir, exist_ok=True)

# %%
# Directory with our training cat pictures
train_Nor_dir = os.path.join(train_dir, 'Normal')
os.makedirs(train_Nor_dir, exist_ok=True)
# Directory with our training cat pictures
train_ABn_dir = os.path.join(train_dir, 'ABnormal')
os.makedirs(train_ABn_dir, exist_ok=True)

# Directory with our training cat pictures
validation_Nor_dir = os.path.join(validation_dir, 'Normal')
os.makedirs(validation_Nor_dir, exist_ok=True)
# Directory with our training cat pictures
validation_ABn_dir = os.path.join(validation_dir, 'ABnormal')
os.makedirs(validation_ABn_dir, exist_ok=True)

#Path images of train
Nor_train = train[train['Class']=='Normal']
Nor_path_train = Nor_train['Path Crop'].tolist() 
ABn_train = train[train['Class']=='Abnormal']
ABn_path_train = ABn_train['Path Crop'].tolist() 

Nor_validation = test[test['Class']=='Normal']
Nor_path_validation = Nor_validation['Path Crop'].tolist() 
ABn_validation = test[test['Class']=='Abnormal']
ABn_path_validation= ABn_validation['Path Crop'].tolist() 

#Train
fnames = Nor_path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)
    
fnames = ABn_path_train  
for fname in fnames:
    dst = os.path.join(train_ABn_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)
  
 #Validation
fnames = Nor_path_validation 
for fname in fnames:
    dst = os.path.join(validation_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)

fnames = ABn_path_validation
for fname in fnames:
    dst = os.path.join(validation_ABn_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    shutil.copyfile(fname, dst)

# %%
print('Train images total : ',len(Nor_path_train)+len(ABn_path_train))
print('Validation images total : ',len(ABn_path_validation)+len(Nor_path_validation))
print('Total images : ',len(Nor_path_train)+len(ABn_path_train)+len(ABn_path_validation)+len(Nor_path_validation))
# Out:
# Train images total :  2282
# Validation images total :  226
# Total images :  2508

# %% [markdown]
# #### Hyper parameters

# %%
batch_size = 50 

width = 150 
height = 150 
input_shape = (height, width, 3) #ขนาด image enter

epochs = 10 #จำนวนรอบในการ Train
NUM_TRAIN = len(Nor_path_train)+len(ABn_path_train)  # จำนวนภาพ Train
NUM_TEST = len(ABn_path_validation)+len(Nor_path_validation) #จำนวนภาพ Test
dropout_rate = 0.2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fc45d76acc5d> in <module>
#       6
#       7 epochs = 10 #จำนวนรอบในการ Train
# ----> 8 NUM_TRAIN = len(Nor_path_train)+len(ABn_path_train)  # จำนวนภาพ Train
#       9 NUM_TEST = len(ABn_path_validation)+len(Nor_path_validation) #จำนวนภาพ Test
#      10 dropout_rate = 0.2
#
# NameError: name 'Nor_path_train' is not defined

# %% [markdown]
# #### Setting data augmentation

# %%
# data augmentation เพื่อลดโอกาสการเกิด overfitting

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
      rescale=1./255, # image input 0-255 --> 0-1 เปลี่ยนค่าสี
      rotation_range=40, # หมุนภาพในองศา
      width_shift_range=0.2, #เปลี่ยนความกว้าง
      height_shift_range=0.2, #ปลี่ยนความสูง
      shear_range=0.2, #ทำให้ภาพเบี้ยว
      zoom_range=0.2, #ซุม image มากสุด 20%
      horizontal_flip=False, #พลิกภาพแบบสุ่มตามแนวนอน
      fill_mode='nearest') 

# Note that the validation data should not be augmented!
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to target height and width.
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        # Since we use categorical_crossentropy loss, we need categorical labels
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        class_mode='binary')
# Out:
# Found 2282 images belonging to 2 classes.
# Found 226 images belonging to 2 classes.

# %% [markdown]
# #### Training

# %%
model2.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=2e-5),
              metrics=['acc'])

#history คือตัวแปรที่จะทำการเก็บประวัติการ Train Model ของเรา
#คำสั่ง Train
history = model2.fit_generator(
      train_generator,#โหลดdataเข้ามา
      steps_per_epoch= NUM_TRAIN //batch_size,
      epochs=epochs,
      validation_data=validation_generator, #validation_data=(x_valid, y_valid): ใส่ data ที่เราแยกไว้เพื่อดูผล Model ว่าเกิด Overfitting เริ่มที่จุดใด
      validation_steps= NUM_TEST //batch_size,
      verbose=1, #โชว์ผลลัพธ์ 0:ปิด
      use_multiprocessing=True, #ใช้ GPU หลายตัว
      workers=1) #ทำพร้อมกันที่ละ 4 ตัว
# Out:
# WARNING:tensorflow:From <ipython-input-34-d67f93889282>:15: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.9134 - acc: 0.5824WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 38s 851ms/step - loss: 0.9134 - acc: 0.5824 - val_loss: 0.5487 - val_acc: 0.7300
# Epoch 2/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.7398 - acc: 0.6483WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 866ms/step - loss: 0.7398 - acc: 0.6483 - val_loss: 0.3845 - val_acc: 0.8350
# Epoch 3/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.6278 - acc: 0.7088WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 858ms/step - loss: 0.6278 - acc: 0.7088 - val_loss: 0.3361 - val_acc: 0.8500
# Epoch 4/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.5790 - acc: 0.7370WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 864ms/step - loss: 0.5790 - acc: 0.7370 - val_loss: 0.2793 - val_acc: 0.8850
# Epoch 5/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.5262 - acc: 0.7612WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 863ms/step - loss: 0.5262 - acc: 0.7612 - val_loss: 0.2810 - val_acc: 0.8700
# Epoch 6/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.4887 - acc: 0.7724WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 857ms/step - loss: 0.4887 - acc: 0.7724 - val_loss: 0.2448 - val_acc: 0.8800
# Epoch 7/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.4750 - acc: 0.7881WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 861ms/step - loss: 0.4750 - acc: 0.7881 - val_loss: 0.2144 - val_acc: 0.9000
# Epoch 8/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.4259 - acc: 0.8033WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 861ms/step - loss: 0.4259 - acc: 0.8033 - val_loss: 0.2064 - val_acc: 0.9100
# Epoch 9/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.4238 - acc: 0.8132WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 39s 858ms/step - loss: 0.4238 - acc: 0.8132 - val_loss: 0.1906 - val_acc: 0.9300
# Epoch 10/10
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - ETA: 0s - loss: 0.4118 - acc: 0.8177WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 45/45 [==============================] - 38s 853ms/step - loss: 0.4118 - acc: 0.8177 - val_loss: 0.1911 - val_acc: 0.9100

# %%
##save model    
os.makedirs("./models", exist_ok=True)
model2.save('./models/ABn_vs_Nor_v2.h5')

# %%
from keras import backend as K
K.clear_session()

from numba import cuda
cuda.select_device(0)
cuda.close()

# %% [markdown]
# # Test Predict

# %%
import pandas as pd
df0 = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_350_.csv')
df0
# Out:
#       Unnamed: 0  Case Abs Position Sub Position     Class Sub_class  \
# 0              0    15           P3          P31  Abnormal      AB01
# 1              1    42           P5          P52  Abnormal      AB01
# 2              2    22           P2           P2  Abnormal      AB01
# 3              3    25           P4          P41  Abnormal      AB01
# 4              4    40           P1           P1  Abnormal      AB01
# 5              5    13           P4          P42  Abnormal      AB01
# 6              6    27           P2           P2  Abnormal      AB01
# 7              7    86           P3          P31  Abnormal      AB01
# 8              8    45           P5          P52  Abnormal      AB01
# 9              9    20           P3          P31  Abnormal      AB01
# 10            10    37           P1           P1  Abnormal      AB01
# 11            11    32           P2           P2  Abnormal      AB01
# 12            12    64           P3          P31  Abnormal      AB01
# 13            13     3           P2           P2  Abnormal      AB01
# 14            14    27           P1           P1  Abnormal      AB01
# 15            15     7           P3          P31  Abnormal      AB01
# 16            16     5           P2           P2  Abnormal      AB01
# 17            17    45           P3          P31  Abnormal      AB01
# 18            18    17           P3          P31  Abnormal      AB01
# 19            19    49           P5          P52  Abnormal      AB01
# 20            20    33           P5          P51  Abnormal      AB01
# 21            21    21           P4          P41  Abnormal      AB01
# 22            22    16           P3          P31  Abnormal      AB01
# 23            23    22           P1           P1  Abnormal      AB01
# 24            24    26           P3          P31  Abnormal      AB01
# 25            25    44           P5          P52  Abnormal      AB01
# 26            26     9           P5          P51  Abnormal      AB01
# 27            27    23           P5          P51  Abnormal      AB01
# 28            28    39           P4          P41  Abnormal      AB01
# 29            29     3           P3          P31  Abnormal      AB01
# ...          ...   ...          ...          ...       ...       ...
# 6089        6089   318           P8           P8    Normal    Normal
# 6090        6090   339           P8           P8    Normal    Normal
# 6091        6091   327           P8           P8    Normal    Normal
# 6092        6092   316           P8           P8    Normal    Normal
# 6093        6093   310           P8           P8    Normal    Normal
# 6094        6094   308           P8           P8    Normal    Normal
# 6095        6095   305           P8           P8    Normal    Normal
# 6096        6096   321           P8           P8    Normal    Normal
# 6097        6097   301           P8           P8    Normal    Normal
# 6098        6098   320           P8           P8    Normal    Normal
# 6099        6099   312           P8           P8    Normal    Normal
# 6100        6100   341           P8           P8    Normal    Normal
# 6101        6101   307           P8           P8    Normal    Normal
# 6102        6102   333           P8           P8    Normal    Normal
# 6103        6103   328           P8           P8    Normal    Normal
# 6104        6104   342           P8           P8    Normal    Normal
# 6105        6105   346           P8           P8    Normal    Normal
# 6106        6106   323           P8           P8    Normal    Normal
# 6107        6107   340           P8           P8    Normal    Normal
# 6108        6108   347           P8           P8    Normal    Normal
# 6109        6109   330           P8           P8    Normal    Normal
# 6110        6110   313           P8           P8    Normal    Normal
# 6111        6111   343           P8           P8    Normal    Normal
# 6112        6112   335           P8           P8    Normal    Normal
# 6113        6113   306           P8           P8    Normal    Normal
# 6114        6114   319           P8           P8    Normal    Normal
# 6115        6115   332           P8           P8    Normal    Normal
# 6116        6116   348           P8           P8    Normal    Normal
# 6117        6117   309           P8           P8    Normal    Normal
# 6118        6118   326           P8           P8    Normal    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 5     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 6     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 7     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 8     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 9     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 10    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 11    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 12    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 13    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 14    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 15    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 16    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 17    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 18    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 19    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 20    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 21    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 22    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 23    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 24    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 25    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 26    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 27    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 28    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 29    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...                                                 ...
# 6089  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6090  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6091  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6092  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6093  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6094  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6095  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6096  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6097  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6098  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6099  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6100  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6101  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6102  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6103  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6104  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6105  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6106  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6107  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6108  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6109  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6110  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6111  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6112  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6113  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6114  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6115  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6116  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6117  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6118  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 5     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 6     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 7     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 8     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 9     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 10    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 11    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 12    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 13    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 14    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 15    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 16    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 17    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 18    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 19    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 20    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 21    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 22    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 23    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 24    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 25    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 26    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 27    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 28    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 29    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...                                                 ...
# 6089  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6090  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6091  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6092  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6093  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6094  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6095  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6096  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6097  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6098  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6099  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6100  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6101  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6102  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6103  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6104  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6105  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6106  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6107  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6108  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6109  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6110  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6111  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6112  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6113  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6114  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6115  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6116  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6117  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 6118  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
# [6119 rows x 8 columns]

# %%
df01 = df0[(df0['Path Crop']!='None' )&(df0['Path Crop']!='Nan')]

# %%
a = df01[df01['Case'].between(1, 10)]
print(a.shape)
print('Normal: ',a[a['Class']=='Normal'].shape)
print('Abnormal: ',a[a['Class']=='Abnormal'].shape)
# a1 = a['Path Crop'].tolist() 
# a1[0]
# Out:
# (415, 8)
# Normal:  (125, 8)
# Abnormal:  (290, 8)

# %%
a
# Out:
#       Unnamed: 0  Case Abs Position Sub Position     Class Sub_class  \
# 13            13     3           P2           P2  Abnormal      AB01
# 15            15     7           P3          P31  Abnormal      AB01
# 16            16     5           P2           P2  Abnormal      AB01
# 26            26     9           P5          P51  Abnormal      AB01
# 29            29     3           P3          P31  Abnormal      AB01
# 33            33     8           P4          P42  Abnormal      AB01
# 34            34     9           P3          P31  Abnormal      AB01
# 43            43     2           P2           P2  Abnormal      AB01
# 49            49     7           P4          P42  Abnormal      AB01
# 59            59     9           P5          P52  Abnormal      AB01
# 82            82     1           P3          P31  Abnormal      AB01
# 84            84     2           P4          P41  Abnormal      AB01
# 87            87     3           P1           P1  Abnormal      AB01
# 99            99     4           P2           P2  Abnormal      AB01
# 107          107     9           P2           P2  Abnormal      AB01
# 108          108     4           P5          P52  Abnormal      AB01
# 113          113    10           P2           P2  Abnormal      AB01
# 115          115    10           P5          P52  Abnormal      AB01
# 121          121     5           P4          P41  Abnormal      AB01
# 135          135     6           P4          P41  Abnormal      AB01
# 136          136     1           P1           P1  Abnormal      AB01
# 150          150     5           P3          P31  Abnormal      AB01
# 159          159     2           P4          P42  Abnormal      AB01
# 162          162     6           P2           P2  Abnormal      AB01
# 163          163    10           P4          P42  Abnormal      AB01
# 165          165     2           P1           P1  Abnormal      AB01
# 168          168     4           P1           P1  Abnormal      AB01
# 191          191     1           P4          P42  Abnormal      AB01
# 201          201     6           P3          P31  Abnormal      AB01
# 205          205     7           P2           P2  Abnormal      AB01
# ...          ...   ...          ...          ...       ...       ...
# 1864        1864     6           P7          P72    Normal    Normal
# 1865        1865     5           P7          P72    Normal    Normal
# 1866        1866     4           P7          P71    Normal    Normal
# 1867        1867     9           P7          P71    Normal    Normal
# 1868        1868     7           P7          P71    Normal    Normal
# 1869        1869     1           P7          P71    Normal    Normal
# 1870        1870     9           P7          P72    Normal    Normal
# 1871        1871     2           P7          P71    Normal    Normal
# 1872        1872     4           P7          P72    Normal    Normal
# 1873        1873     8           P7          P71    Normal    Normal
# 1874        1874     7           P7          P72    Normal    Normal
# 1875        1875    10           P7          P71    Normal    Normal
# 1876        1876     5           P7          P71    Normal    Normal
# 1877        1877     8           P7          P72    Normal    Normal
# 1878        1878     6           P7          P71    Normal    Normal
# 1879        1879     1           P7          P72    Normal    Normal
# 1880        1880     2           P7          P72    Normal    Normal
# 1881        1881     3           P7          P71    Normal    Normal
# 1882        1882     3           P7          P72    Normal    Normal
# 1883        1883    10           P7          P72    Normal    Normal
# 1884        1884     7           P8           P8    Normal    Normal
# 1885        1885     4           P8           P8    Normal    Normal
# 1886        1886    10           P8           P8    Normal    Normal
# 1887        1887     3           P8           P8    Normal    Normal
# 1888        1888     5           P8           P8    Normal    Normal
# 1889        1889     1           P8           P8    Normal    Normal
# 1890        1890     6           P8           P8    Normal    Normal
# 1891        1891     9           P8           P8    Normal    Normal
# 1892        1892     8           P8           P8    Normal    Normal
# 1893        1893     2           P8           P8    Normal    Normal
#
#                                               Path Full  \
# 13    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 15    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 16    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 26    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 29    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 33    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 34    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 43    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 49    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 59    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 82    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 84    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 87    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 99    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 107   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 108   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 113   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 115   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 121   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 135   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 136   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 150   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 159   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 162   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 163   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 165   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 168   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 191   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 201   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 205   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...                                                 ...
# 1864  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1865  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1866  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1867  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1868  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1869  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1870  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1871  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1872  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1873  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1874  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1875  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1876  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1877  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1878  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1879  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1880  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1881  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1882  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1883  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1884  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1885  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1886  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1887  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1888  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1889  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1890  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1891  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1892  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1893  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
#                                               Path Crop
# 13    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 15    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 16    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 26    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 29    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 33    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 34    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 43    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 49    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 59    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 82    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 84    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 87    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 99    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 107   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 108   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 113   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 115   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 121   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 135   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 136   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 150   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 159   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 162   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 163   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 165   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 168   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 191   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 201   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 205   /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...                                                 ...
# 1864  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1865  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1866  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1867  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1868  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1869  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1870  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1871  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1872  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1873  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1874  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1875  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1876  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1877  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1878  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1879  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1880  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1881  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1882  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1883  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1884  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1885  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1886  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1887  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1888  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1889  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1890  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1891  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1892  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1893  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
# [415 rows x 8 columns]

# %% [markdown]
# ### Load model

# %%
import sys
sys.path.append('/media/tohn/SSD/Nor_ABnor_Network/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})
# Out:
# Using TensorFlow backend.

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/Nor_ABnor_Network/content/efficientnet_keras_transfer_learning/models/ABn_vs_Nor.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 1280)              4049564
# _________________________________________________________________
# fc_out (Dense)               (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 782,721
# Non-trainable params: 3,268,124
# _________________________________________________________________

# %% [markdown]
# ### Prediction

# %%
width = 150 
height = 150 
input_shape = (height, width, 3) #ขนาด image enter

# %%
from tensorflow.keras.preprocessing import image
import pandas as pd

# %%
 img_path =a[a['Class']=='Normal']['Path Crop'].tolist()

# %%
imgg = img_path[-1]

# %%
def predict_image(img_path):
    # Read the image and resize it
    img = image.load_img(img_path, target_size=(height, width))
    # Convert it to a Numpy array with target shape.
    x = image.img_to_array(img)
    # Reshape
    x = x.reshape((1,) + x.shape)
    x /= 255.
    result = model.predict([x])[0][0]
    if result > 0.5:
        classs = "Normal"
    else:
        classs = "Abnormal"
        result = 1 - result
    return classs,result

# %%
predict_image(imgg)
# Out:
# ('Abnormal', 0.948163602501154)

# %%
from tensorflow.keras.preprocessing import image

def predict_image(img_path):
    # Read the image and resize it
    img = image.load_img(img_path, target_size=(height, width))
    # Convert it to a Numpy array with target shape.
    x = image.img_to_array(img)
    # Reshape
    x = x.reshape((1,) + x.shape)
    x /= 255.
    result = model.predict([x])[0][0]
    if result > 0.5:
        classs = "Normal"
    else:
        classs = "Abnormal"
        result = 1 - result
    return classs,result

classe =['Normal','Abnormal']
results = list()
# predlist,problist = list(), list()

for i in classe:
    img_path =a[a['Class']==i]['Path Crop'].tolist()
    for j in img_path:
    #แก้ถึงตรงนี้   
        classs,result = predict_image(img_path)
#     predlist.append(classs)
#     problist.append(result)
#     act_true = i
    results.append({'2Actual':i,'3Predicted':classs, '4Class_prob':result,'path':j})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ea981589b1de> in <module>
#      25     for j in img_path:
#      26     #แก้ถึงตรงนี้
# ---> 27         classs,result = predict_image(img_path)
#      28 #     predlist.append(classs)
#      29 #     problist.append(result)
#
# <ipython-input-22-ea981589b1de> in predict_image(img_path)
#       3 def predict_image(img_path):
#       4     # Read the image and resize it
# ----> 5     img = image.load_img(img_path, target_size=(height, width))
#       6     # Convert it to a Numpy array with target shape.
#       7     x = image.img_to_array(img)
#
# ~/miniconda3/envs/eff/lib/python3.6/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
# classe =['P1','P2','P31','P32','P41','P42','P51','P52','P61','P62','P71','P72','P8',]
# results = list()

# for i in classe:
#     img_path =val[val['Sub Position']==i]['Path Crop'].tolist()
#     for j in img_path:
#         img = image.load_img(j, target_size=(height, width))
#             # Convert it to a Numpy array with target shape.
#         x = image.img_to_array(img)
#             # Reshape
#         x = x.reshape((1,) + x.shape)
#         x /= 255.
#         result = model.predict([x])[0]
#         n = 13
#         avgDists = result
#         idxs = avgDists.argsort()[::-1][:n] #sort max
#         predlist,problist = list(), list()
#         for m in idxs:
#             pred =  classe[m]
#             prob = result[m]
#             predlist.append(pred)
#             problist.append(prob)
#         act_true = i
#         prob_max = problist[0]
#         pred_max = predlist[0]

#         results.append({'2Actual':act_true,'3Predicted':pred_max, '4Class_prob':prob_max, '5moreprop':problist[0:3],'6morepred':predlist[0:3],'path':j})

# %%
resultss = pd.DataFrame(results)
resultss

# %%
# os.chdir( '/home/yupaporn/codes/USAI/')
# resultss.to_csv('result_Nor_Abn.csv')

# %%
# from tensorflow.keras.preprocessing import image

# def predict_image(img_path):
#     # Read the image and resize it
#     img = image.load_img(img_path, target_size=(height, width))
#     # Convert it to a Numpy array with target shape.
#     x = image.img_to_array(img)
#     # Reshape
#     x = x.reshape((1,) + x.shape)
#     x /= 255.
#     result = model2.predict([x])[0][0]
#     if result > 0.5:
#         classs = "Normal"
#     else:
#         classs = "Abnormal"
#         result = 1 - result
#     return classs,result

# print(predict_image(img))

# %%
# classs,result = predict_image(img_path)
