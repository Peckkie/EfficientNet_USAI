# %%
import pandas as pd
import shutil

# %%
df = pd.read_csv (r'/home/yupaporn/codes/USAI/detail1_250.csv')
df
# Out:
#       Unnamed: 0  Case Abs Position Sub Position   Class Sub_class  \
# 0              0     5           P1           P1  Normal    Normal
# 1              1     9           P1           P1  Normal    Normal
# 2              2     6           P1           P1  Normal    Normal
# 3              3     4           P1           P1  Normal    Normal
# 4              4     3           P1           P1  Normal    Normal
# 5              5     2           P1           P1  Normal    Normal
# 6              6     8           P1           P1  Normal    Normal
# 7              7    10           P1           P1  Normal    Normal
# 8              8     7           P1           P1  Normal    Normal
# 9              9     1           P1           P1  Normal    Normal
# 10            10    39           P1           P1  Normal    Normal
# 11            11    54           P1           P1  Normal    Normal
# 12            12    37           P1           P1  Normal    Normal
# 13            13    57           P1           P1  Normal    Normal
# 14            14    58           P1           P1  Normal    Normal
# 15            15    42           P1           P1  Normal    Normal
# 16            16    43           P1           P1  Normal    Normal
# 17            17    33           P1           P1  Normal    Normal
# 18            18    29           P1           P1  Normal    Normal
# 19            19    55           P1           P1  Normal    Normal
# 20            20    48           P1           P1  Normal    Normal
# 21            21    59           P1           P1  Normal    Normal
# 22            22    51           P1           P1  Normal    Normal
# 23            23    11           P1           P1  Normal    Normal
# 24            24    24           P1           P1  Normal    Normal
# 25            25    44           P1           P1  Normal    Normal
# 26            26    35           P1           P1  Normal    Normal
# 27            27    60           P1           P1  Normal    Normal
# 28            28    40           P1           P1  Normal    Normal
# 29            29    30           P1           P1  Normal    Normal
# ...          ...   ...          ...          ...     ...       ...
# 3029        3029   229           P8           P8  Normal    Normal
# 3030        3030   248           P8           P8  Normal    Normal
# 3031        3031   223           P8           P8  Normal    Normal
# 3032        3032   247           P8           P8  Normal    Normal
# 3033        3033   249           P8           P8  Normal    Normal
# 3034        3034   225           P8           P8  Normal    Normal
# 3035        3035   233           P8           P8  Normal    Normal
# 3036        3036   227           P8           P8  Normal    Normal
# 3037        3037   236           P8           P8  Normal    Normal
# 3038        3038   216           P8           P8  Normal    Normal
# 3039        3039   212           P8           P8  Normal    Normal
# 3040        3040   241           P8           P8  Normal    Normal
# 3041        3041   210           P8           P8  Normal    Normal
# 3042        3042   202           P8           P8  Normal    Normal
# 3043        3043   246           P8           P8  Normal    Normal
# 3044        3044   245           P8           P8  Normal    Normal
# 3045        3045   244           P8           P8  Normal    Normal
# 3046        3046   230           P8           P8  Normal    Normal
# 3047        3047   243           P8           P8  Normal    Normal
# 3048        3048   220           P8           P8  Normal    Normal
# 3049        3049   226           P8           P8  Normal    Normal
# 3050        3050   232           P8           P8  Normal    Normal
# 3051        3051   214           P8           P8  Normal    Normal
# 3052        3052   228           P8           P8  Normal    Normal
# 3053        3053   209           P8           P8  Normal    Normal
# 3054        3054   215           P8           P8  Normal    Normal
# 3055        3055   231           P8           P8  Normal    Normal
# 3056        3056   205           P8           P8  Normal    Normal
# 3057        3057   201           P8           P8  Normal    Normal
# 3058        3058   203           P8           P8  Normal    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
# [3059 rows x 8 columns]

# %%
classes = ['P1','P2','P31','P32','P41','P42','P51','P52','P61','P62','P71','P72','P8']
len(classes)
# Out:
# 13

# %%
print(len(set(df['Sub Position'])))
print(set(df['Sub Position']))
df.shape
# Out:
# 19
# {'P71', 'P11', 'P7', 'P32', 'P61', 'P8', 'P6', 'P41', 'P42', 'P51', 'P31', 'P1', 'P52', 'P72', 'P2', 'P12', 'P62', 'P4', 'P43'}
# (3059, 8)

# %%
df1 = df
df01 = df1.replace({'Sub Position': {'P11':'P1','P12':'P1','P4':'P41','P43':'P41','P6':'P61','P7':'P71'}})
print(len(set(df01['Sub Position'])))
print(set(df01['Sub Position']))
df1.shape
# Out:
# 13
# {'P71', 'P32', 'P61', 'P8', 'P41', 'P42', 'P51', 'P31', 'P1', 'P52', 'P72', 'P2', 'P62'}
# (3059, 8)

# %% [markdown]
# # Clone efficientnet repo

# %%
import os
# os.path.abspath('/media/tohn/SSD/Efficient_USAI')
os.chdir('/media/tohn/SSD/Sub_Efficient_USAI')
# !ls
  #choose gpu on processing 
os.environ["CUDA_VISIBLE_DEVICES"]="0" # second gpu
# Out:
# content  my_logs

# %%
import os
# %cd content
if not os.path.isdir("efficientnet_keras_transfer_learning"):
  # !git clone https://github.com/Tony607/efficientnet_keras_transfer_learning
# %cd efficientnet_keras_transfer_learning/
# Out:
# /media/tohn/SSD/Sub_Efficient_USAI/content
# /media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning

# %% [markdown]
# # การเเบ่งข้อมูล  train/validation/test sets

# %%
# The directory where we will
base_dir = './data/views'
os.makedirs(base_dir, exist_ok=True)

# Directories for our training,
# validation and test splits
train_dir = os.path.join(base_dir, 'train')
os.makedirs(train_dir, exist_ok=True)
validation_dir = os.path.join(base_dir, 'validation')
os.makedirs(validation_dir, exist_ok=True)
test_dir = os.path.join(base_dir, 'test')
os.makedirs(test_dir, exist_ok=True)

# %%
# classes = ['P1','P2','P31','P32','P41','P42','P51','P52','P6','P62','P71','P72','P8','None']
# len(classes)

# %%
# Directory with our training cat pictures
validation_P1_dir = os.path.join(validation_dir, 'P1')
os.makedirs(validation_P1_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P2_dir = os.path.join(validation_dir, 'P2')
os.makedirs(validation_P2_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P31_dir = os.path.join(validation_dir, 'P31')
os.makedirs(validation_P31_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P32_dir = os.path.join(validation_dir, 'P32')
os.makedirs(validation_P32_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P41_dir = os.path.join(validation_dir, 'P41')
os.makedirs(validation_P41_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P42_dir = os.path.join(validation_dir, 'P42')
os.makedirs(validation_P42_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P51_dir = os.path.join(validation_dir, 'P51')
os.makedirs(validation_P51_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P52_dir = os.path.join(validation_dir, 'P52')
os.makedirs(validation_P52_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P61_dir = os.path.join(validation_dir, 'P61')
os.makedirs(validation_P61_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P62_dir = os.path.join(validation_dir, 'P62')
os.makedirs(validation_P62_dir, exist_ok=True)
validation_P71_dir = os.path.join(validation_dir, 'P71')
os.makedirs(validation_P71_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P72_dir = os.path.join(validation_dir, 'P72')
os.makedirs(validation_P72_dir, exist_ok=True)
# Directory with our training cat pictures
validation_P8_dir = os.path.join(validation_dir, 'P8')
os.makedirs(validation_P8_dir, exist_ok=True)


# Directory with our training cat pictures
train_P1_dir = os.path.join(train_dir, 'P1')
os.makedirs(train_P1_dir, exist_ok=True)
# Directory with our training cat pictures
train_P2_dir = os.path.join(train_dir, 'P2')
os.makedirs(train_P2_dir, exist_ok=True)
# Directory with our training cat pictures
train_P31_dir = os.path.join(train_dir, 'P31')
os.makedirs(train_P31_dir, exist_ok=True)
# Directory with our training cat pictures
train_P32_dir = os.path.join(train_dir, 'P32')
os.makedirs(train_P32_dir, exist_ok=True)
# Directory with our training cat pictures
train_P41_dir = os.path.join(train_dir, 'P41')
os.makedirs(train_P41_dir, exist_ok=True)
# Directory with our training cat pictures
train_P42_dir = os.path.join(train_dir, 'P42')
os.makedirs(train_P42_dir, exist_ok=True)
# Directory with our training cat pictures
train_P51_dir = os.path.join(train_dir, 'P51')
os.makedirs(train_P51_dir, exist_ok=True)
# Directory with our training cat pictures
train_P52_dir = os.path.join(train_dir, 'P52')
os.makedirs(train_P52_dir, exist_ok=True)
# Directory with our training cat pictures
train_P61_dir = os.path.join(train_dir, 'P61')
os.makedirs(train_P61_dir, exist_ok=True)
# Directory with our training cat pictures
train_P62_dir = os.path.join(train_dir, 'P62')
os.makedirs(train_P62_dir, exist_ok=True)
train_P71_dir = os.path.join(train_dir, 'P71')
os.makedirs(train_P71_dir, exist_ok=True)
# Directory with our training cat pictures
train_P72_dir = os.path.join(train_dir, 'P72')
os.makedirs(train_P72_dir, exist_ok=True)
# Directory with our training cat pictures
train_P8_dir = os.path.join(train_dir, 'P8')
os.makedirs(train_P8_dir, exist_ok=True)

# %% [markdown]
# # Copy views images to rain_views_dir

# %%
df1 =df01[df01['Path Crop'] != 'None']
df1
# Out:
#       Unnamed: 0  Case Abs Position Sub Position   Class Sub_class  \
# 0              0     5           P1           P1  Normal    Normal
# 1              1     9           P1           P1  Normal    Normal
# 2              2     6           P1           P1  Normal    Normal
# 3              3     4           P1           P1  Normal    Normal
# 4              4     3           P1           P1  Normal    Normal
# 5              5     2           P1           P1  Normal    Normal
# 6              6     8           P1           P1  Normal    Normal
# 7              7    10           P1           P1  Normal    Normal
# 8              8     7           P1           P1  Normal    Normal
# 9              9     1           P1           P1  Normal    Normal
# 10            10    39           P1           P1  Normal    Normal
# 11            11    54           P1           P1  Normal    Normal
# 12            12    37           P1           P1  Normal    Normal
# 13            13    57           P1           P1  Normal    Normal
# 14            14    58           P1           P1  Normal    Normal
# 15            15    42           P1           P1  Normal    Normal
# 16            16    43           P1           P1  Normal    Normal
# 17            17    33           P1           P1  Normal    Normal
# 18            18    29           P1           P1  Normal    Normal
# 19            19    55           P1           P1  Normal    Normal
# 20            20    48           P1           P1  Normal    Normal
# 21            21    59           P1           P1  Normal    Normal
# 22            22    51           P1           P1  Normal    Normal
# 23            23    11           P1           P1  Normal    Normal
# 24            24    24           P1           P1  Normal    Normal
# 25            25    44           P1           P1  Normal    Normal
# 26            26    35           P1           P1  Normal    Normal
# 27            27    60           P1           P1  Normal    Normal
# 28            28    40           P1           P1  Normal    Normal
# 29            29    30           P1           P1  Normal    Normal
# ...          ...   ...          ...          ...     ...       ...
# 3029        3029   229           P8           P8  Normal    Normal
# 3030        3030   248           P8           P8  Normal    Normal
# 3031        3031   223           P8           P8  Normal    Normal
# 3032        3032   247           P8           P8  Normal    Normal
# 3033        3033   249           P8           P8  Normal    Normal
# 3034        3034   225           P8           P8  Normal    Normal
# 3035        3035   233           P8           P8  Normal    Normal
# 3036        3036   227           P8           P8  Normal    Normal
# 3037        3037   236           P8           P8  Normal    Normal
# 3038        3038   216           P8           P8  Normal    Normal
# 3039        3039   212           P8           P8  Normal    Normal
# 3040        3040   241           P8           P8  Normal    Normal
# 3041        3041   210           P8           P8  Normal    Normal
# 3042        3042   202           P8           P8  Normal    Normal
# 3043        3043   246           P8           P8  Normal    Normal
# 3044        3044   245           P8           P8  Normal    Normal
# 3045        3045   244           P8           P8  Normal    Normal
# 3046        3046   230           P8           P8  Normal    Normal
# 3047        3047   243           P8           P8  Normal    Normal
# 3048        3048   220           P8           P8  Normal    Normal
# 3049        3049   226           P8           P8  Normal    Normal
# 3050        3050   232           P8           P8  Normal    Normal
# 3051        3051   214           P8           P8  Normal    Normal
# 3052        3052   228           P8           P8  Normal    Normal
# 3053        3053   209           P8           P8  Normal    Normal
# 3054        3054   215           P8           P8  Normal    Normal
# 3055        3055   231           P8           P8  Normal    Normal
# 3056        3056   205           P8           P8  Normal    Normal
# 3057        3057   201           P8           P8  Normal    Normal
# 3058        3058   203           P8           P8  Normal    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
#                                               Path Crop
# 0     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9     /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ...                                                 ...
# 3029  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3030  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3031  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3032  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3033  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3034  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3035  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3036  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3037  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3038  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3039  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3040  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3041  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3042  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3043  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3044  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3045  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3046  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3047  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3048  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3049  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3050  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3051  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3052  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3053  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3054  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3055  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3056  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3057  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 3058  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
# [3050 rows x 8 columns]

# %%
# classes = ['P1','P2','P31','P32','P41','P42','P51','P52','P61','P62','P71','P72','P8','None']

# %%
#Create Path images
val = df1[df1['Case'].between(1, 10)]
train = df1[df1['Case'].between(11, 250)]

#Path images of validation
p1_val = val[val['Sub Position']=='P1' ]
p1_path_val = p1_val['Path Crop'].tolist() 
p2_val = val[val['Sub Position']=='P2' ]
p2_path_val = p2_val['Path Crop'].tolist() 
p31_val = val[val['Sub Position']=='P31' ]
p31_path_val = p31_val['Path Crop'].tolist() 
p32_val = val[val['Sub Position']=='P32' ]
p32_path_val = p32_val['Path Crop'].tolist()
p41_val = val[val['Sub Position']=='P41' ]
p41_path_val = p41_val['Path Crop'].tolist()
p42_val = val[val['Sub Position']=='P42' ]
p42_path_val = p42_val['Path Crop'].tolist() 
p51_val = val[val['Sub Position']=='P51' ]
p51_path_val = p51_val['Path Crop'].tolist()
p52_val = val[val['Sub Position']=='P52' ]
p52_path_val = p52_val['Path Crop'].tolist() 
p61_val = val[val['Sub Position']=='P61' ]
p61_path_val = p61_val['Path Crop'].tolist()
p62_val = val[val['Sub Position']=='P62' ]
p62_path_val = p62_val['Path Crop'].tolist() 
p71_val = val[val['Sub Position']=='P71' ]
p71_path_val = p71_val['Path Crop'].tolist() 
p72_val = val[val['Sub Position']=='P72' ]
p72_path_val = p72_val['Path Crop'].tolist() 
p8_val = val[val['Sub Position']=='P8' ]
p8_path_val = p8_val['Path Crop'].tolist() 

#Path images of train
p1_train = train[train['Sub Position']=='P1' ]
p1_path_train = p1_train['Path Crop'].tolist() 
p2_train = train[train['Sub Position']=='P2' ]
p2_path_train = p2_train['Path Crop'].tolist() 
p31_train = train[train['Sub Position']=='P31' ]
p31_path_train = p31_train['Path Crop'].tolist()
p32_train = train[train['Sub Position']=='P32' ]
p32_path_train = p32_train['Path Crop'].tolist()
p41_train = train[train['Sub Position']=='P41' ]
p41_path_train = p41_train['Path Crop'].tolist()
p42_train = train[train['Sub Position']=='P42' ]
p42_path_train = p42_train['Path Crop'].tolist()
p51_train = train[train['Sub Position']=='P51' ]
p51_path_train = p51_train['Path Crop'].tolist()
p52_train = train[train['Sub Position']=='P52' ]
p52_path_train = p52_train['Path Crop'].tolist() 
p61_train = train[train['Sub Position']=='P61' ]
p61_path_train = p61_train['Path Crop'].tolist()
p62_train = train[train['Sub Position']=='P62' ]
p62_path_train = p62_train['Path Crop'].tolist()
p71_train = train[train['Sub Position']=='P71' ]
p71_path_train = p71_train['Path Crop'].tolist()
p72_train = train[train['Sub Position']=='P72' ]
p72_path_train = p72_train['Path Crop'].tolist()
p8_train = train[train['Sub Position']=='P8' ]
p8_path_train = p8_train['Path Crop'].tolist()

# %%
# copy images each view to validation_view_dir
fnames = p1_path_val  
for fname in fnames:
    dst = os.path.join(validation_P1_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p2_path_val  
for fname in fnames:
    dst = os.path.join(validation_P2_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p31_path_val  
for fname in fnames:
    dst = os.path.join(validation_P31_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p32_path_val  
for fname in fnames:
    dst = os.path.join(validation_P32_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p41_path_val  
for fname in fnames:
    dst = os.path.join(validation_P41_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)  

fnames = p42_path_val  
for fname in fnames:
    dst = os.path.join(validation_P42_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)  
    
fnames = p51_path_val  
for fname in fnames:
    dst = os.path.join(validation_P51_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p52_path_val  
for fname in fnames:
    dst = os.path.join(validation_P52_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p61_path_val  
for fname in fnames:
    dst = os.path.join(validation_P61_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p62_path_val  
for fname in fnames:
    dst = os.path.join(validation_P62_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p71_path_val  
for fname in fnames:
    dst = os.path.join(validation_P71_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p72_path_val  
for fname in fnames:
    dst = os.path.join(validation_P72_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p8_path_val  
for fname in fnames:
    dst = os.path.join(validation_P8_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# copy images each view to train_view_dir

    fnames = p1_path_train  
for fname in fnames:
    dst = os.path.join(train_P1_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p2_path_train  
for fname in fnames:
    dst = os.path.join(train_P2_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p31_path_train  
for fname in fnames:
    dst = os.path.join(train_P31_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p32_path_train  
for fname in fnames:
    dst = os.path.join(train_P32_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p41_path_train  
for fname in fnames:
    dst = os.path.join(train_P41_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p42_path_train  
for fname in fnames:
    dst = os.path.join(train_P42_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p51_path_train  
for fname in fnames:
    dst = os.path.join(train_P51_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

fnames = p52_path_train  
for fname in fnames:
    dst = os.path.join(train_P52_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p61_path_train  
for fname in fnames:
    dst = os.path.join(train_P61_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p62_path_train  
for fname in fnames:
    dst = os.path.join(train_P62_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p71_path_train  
for fname in fnames:
    dst = os.path.join(train_P71_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
     
fnames = p72_path_train  
for fname in fnames:
    dst = os.path.join(train_P72_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)
    
fnames = p8_path_train  
for fname in fnames:
    dst = os.path.join(train_P8_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# %%
#Show number of train&val

print('total training images:', len(os.listdir(train_P1_dir))+len(os.listdir(train_P2_dir))+len(os.listdir(train_P31_dir))+len(os.listdir(train_P32_dir))
      +len(os.listdir(train_P41_dir))+len(os.listdir(train_P42_dir))+len(os.listdir(train_P51_dir))+len(os.listdir(train_P52_dir))+len(os.listdir(train_P61_dir))
      +len(os.listdir(train_P62_dir))+len(os.listdir(train_P71_dir))+len(os.listdir(train_P72_dir))+len(os.listdir(train_P8_dir)))
print('total training P1 images:', len(os.listdir(train_P1_dir)))
print('total training P2 images:', len(os.listdir(train_P2_dir)))
print('total training P31 images:', len(os.listdir(train_P31_dir)))
print('total training P32 images:', len(os.listdir(train_P32_dir)))
print('total training P41 images:', len(os.listdir(train_P41_dir)))
print('total training P42 images:', len(os.listdir(train_P42_dir)))
print('total training P51 images:', len(os.listdir(train_P51_dir)))
print('total training P52 images:', len(os.listdir(train_P52_dir)))
print('total training P61 images:', len(os.listdir(train_P61_dir)))
print('total training P62 images:', len(os.listdir(train_P62_dir)))
print('total training P71 images:', len(os.listdir(train_P71_dir)))
print('total training P72 images:', len(os.listdir(train_P72_dir)))
print('total training P8 images:', len(os.listdir(train_P8_dir)),'\n')

print('total training images:', len(os.listdir(validation_P1_dir))+len(os.listdir(validation_P2_dir))+len(os.listdir(validation_P31_dir))
      +len(os.listdir(validation_P32_dir))+len(os.listdir(validation_P41_dir))+len(os.listdir(validation_P42_dir))+len(os.listdir(validation_P51_dir))
      +len(os.listdir(validation_P52_dir))+len(os.listdir(validation_P61_dir))+len(os.listdir(validation_P62_dir))+len(os.listdir(validation_P71_dir))
      +len(os.listdir(validation_P72_dir))+len(os.listdir(validation_P8_dir)))
print('total validation P1 images:', len(os.listdir(validation_P1_dir)))
print('total validation P2 images:', len(os.listdir(validation_P2_dir)))
print('total training P31 images:', len(os.listdir(validation_P31_dir)))
print('total training P32 images:', len(os.listdir(validation_P32_dir)))
print('total training P41 images:', len(os.listdir(validation_P41_dir)))
print('total training P42 images:', len(os.listdir(validation_P42_dir)))
print('total training P51 images:', len(os.listdir(validation_P51_dir)))
print('total training P52 images:', len(os.listdir(validation_P52_dir)))
print('total training P61 images:', len(os.listdir(validation_P61_dir)))
print('total training P62 images:', len(os.listdir(validation_P62_dir)))
print('total training P71 images:', len(os.listdir(validation_P71_dir)))
print('total training P72 images:', len(os.listdir(validation_P72_dir)))
print('total training P8 images:', len(os.listdir(validation_P8_dir)))
# Out:
# total training images: 2914
# total training P1 images: 242
# total training P2 images: 239
# total training P31 images: 240
# total training P32 images: 241
# total training P41 images: 242
# total training P42 images: 238
# total training P51 images: 240
# total training P52 images: 240
# total training P61 images: 240
# total training P62 images: 61
# total training P71 images: 226
# total training P72 images: 224
# total training P8 images: 241
#
# total training images: 125
# total validation P1 images: 10
# total validation P2 images: 10
# total training P31 images: 10
# total training P32 images: 10
# total training P41 images: 11
# total training P42 images: 10
# total training P51 images: 10
# total training P52 images: 10
# total training P61 images: 10
# total training P62 images: 4
# total training P71 images: 10
# total training P72 images: 10
# total training P8 images: 10

# %% [markdown]
# # Trainning EfficientNet

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
import os
import glob
import shutil
import sys
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from IPython.display import Image
from tensorflow.keras import callbacks
# %matplotlib inline

# %% [markdown]
# ### Hyper parameters

# %%
#only have 2 label
batch_size = 50 #จำนวน data ที่ส่งไป Train ในแต่ละครั้ง จนครบจำนวนเต็ม x_train

width = 150 
height = 150 
input_shape = (height, width, 3) #ขนาด image enter

epochs = 5 #จำนวนรอบในการ Train
NUM_TRAIN = 2914# จำนวนภาพ Train
NUM_TEST = 125 #จำนวนภาพ Test
dropout_rate = 0.2 #คือการปิดบาง Node หรือเรียกว่าทำการ Drop Out ไป ซึ่งขึ้นกับการตั้งค่าว่าจะให้ลืมไปกี่เปอร์เซนต์ดี ช่วยในการแก้ปัญหา Overfitting

# %% [markdown]
# ### Import efficientnet and load the conv base model

# %%
# Options: EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3
# Higher the number, the more complex the model is.

from efficientnet import EfficientNetB3 as Net
from efficientnet import center_crop_and_resize, preprocess_input
# Out:
# Using TensorFlow backend.

# %%
# loading pretrained conv base model

conv_base = Net(weights='imagenet', include_top=False, input_shape=input_shape) # ไม่โหลด weights ของ layer สุดท้าย  include_top=False
# Out:
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b3_imagenet_1000_notop.h5
# 43974656/43966704 [==============================] - 6s 0us/step

# %% [markdown]
# ### Setting data augmentation

# %%
# data augmentation เพื่อลดโอกาสการเกิด overfitting

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
      rescale=1./255, # image input 0-255 --> 0-1 เปลี่ยนค่าสี
      rotation_range=40, # หมุนภาพในองศา
      width_shift_range=0.2, #เปลี่ยนความกว้าง
      height_shift_range=0.2, #ปลี่ยนความสูง
      shear_range=0.2, #ทำให้ภาพเบี้ยว
      zoom_range=0.2, #ซุม image มากสุด 20%
      horizontal_flip=True, #พลิกภาพแบบสุ่มตามแนวนอน
      fill_mode='nearest') 

# Note that the validation data should not be augmented!
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to target height and width.
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        # Since we use categorical_crossentropy loss, we need categorical labels
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(height, width),
        batch_size=batch_size,
        color_mode= 'rgb',
        class_mode='categorical')
# Out:
# Found 2914 images belonging to 13 classes.
# Found 125 images belonging to 13 classes.

# %% [markdown]
# ### Show architecture model

# %%
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalMaxPooling2D(name="gap"))
# model.add(layers.Flatten(name="flatten"))
if dropout_rate > 0:
    model.add(layers.Dropout(dropout_rate, name="dropout_out"))
# model.add(layers.Dense(256, activation='relu', name="fc1"))
model.add(layers.Dense(13, activation='softmax', name="fc_out"))        #class --> 13 **Sub

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b3 (Model)      (None, 5, 5, 1536)        10783528
# _________________________________________________________________
# gap (GlobalMaxPooling2D)     (None, 1536)              0
# _________________________________________________________________
# dropout_out (Dropout)        (None, 1536)              0
# _________________________________________________________________
# fc_out (Dense)               (None, 13)                19981
# =================================================================
# Total params: 10,803,509
# Trainable params: 10,716,213
# Non-trainable params: 87,296
# _________________________________________________________________

# %%
print('This is the number of trainable layers '
      'before freezing the conv base:', len(model.trainable_weights))

conv_base.trainable = False  # freeze เพื่อรักษา convolutional base's weight

print('This is the number of trainable layers '
      'after freezing the conv base:', len(model.trainable_weights))  #freez แล้วจะเหลือ max pool and dense
# Out:
# This is the number of trainable layers before freezing the conv base: 340
# This is the number of trainable layers after freezing the conv base: 2

# %% [markdown]
# ### Training

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=2e-5),
              metrics=['acc'])

#history คือตัวแปรที่จะทำการเก็บประวัติการ Train Model ของเรา
#คำสั่ง Train
history = model.fit_generator(
      train_generator,#โหลดdataเข้ามา
      steps_per_epoch= NUM_TRAIN //batch_size,
      epochs=epochs,
      validation_data=validation_generator, #validation_data=(x_valid, y_valid): ใส่ data ที่เราแยกไว้เพื่อดูผล Model ว่าเกิด Overfitting เริ่มที่จุดใด
      validation_steps= NUM_TEST //batch_size,
      verbose=1, #โชว์ผลลัพธ์ 0:ปิด
      use_multiprocessing=True, #ใช้ GPU หลายตัว
      workers=1) #ทำพร้อมกันที่ละ 4 ตัว
# Out:
# WARNING:tensorflow:From <ipython-input-26-5a648aed815f>:15: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - ETA: 0s - loss: 7.5645 - acc: 0.0555WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - 30s 512ms/step - loss: 7.5645 - acc: 0.0555 - val_loss: 5.3786 - val_acc: 0.0900
# Epoch 2/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - ETA: 0s - loss: 5.6687 - acc: 0.0810WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - 30s 512ms/step - loss: 5.6687 - acc: 0.0810 - val_loss: 4.0871 - val_acc: 0.0600
# Epoch 3/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - ETA: 0s - loss: 5.2454 - acc: 0.0810WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - 30s 514ms/step - loss: 5.2454 - acc: 0.0810 - val_loss: 3.5110 - val_acc: 0.0900
# Epoch 4/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - ETA: 0s - loss: 4.9264 - acc: 0.0897WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - 30s 511ms/step - loss: 4.9264 - acc: 0.0897 - val_loss: 3.3422 - val_acc: 0.1200
# Epoch 5/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - ETA: 0s - loss: 4.8930 - acc: 0.0943WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - 30s 524ms/step - loss: 4.8930 - acc: 0.0943 - val_loss: 3.2923 - val_acc: 0.1000

# %%
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv('hist_df.csv')

# %% [markdown]
# ### Plot training performance

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_x = range(len(acc))

plt.plot(epochs_x, acc,'b', linestyle='--', lw=1, label='Training acc')
plt.plot(epochs_x, val_acc, 'r', lw=1, label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs_x, loss,'b', linestyle='--', lw=1,  label='Training loss')
plt.plot(epochs_x, val_loss, 'r', lw=1,  label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Fine tuning last several layers.
# ### The steps for fine-tuning a network are as follow:
#
# 1) Add your custom network on top of an already trained base network.
#
# 2) Freeze the base network.
#
# 3) Train the part you added.
#
# 4) Unfreeze some layers in the base network.
#
# 5) Jointly train both these layers and the part you added.
#
# ทำไปแล้ว 3 ขั้นตอนเพื่อที่จะหาว่า layers ใดควรที่จะ unfreeze

# %%
#plot the Keras model เพื่อหา  layers ที่จะ unfreeze

from tensorflow.keras.utils import plot_model
plot_model(model, to_file='conv_base.png', show_shapes=True)
from IPython.display import Image
Image(filename='conv_base.png')

# %% [markdown]
# # Test Predict R1

# %% [markdown]
# ### Load model

# %%
import sys
sys.path.append('/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning/models/Sub_b0_c11_250.h5")

# %% [markdown]
# ### Prediction

# %%
val = df1[df1['Case'].between(1, 10)]

# %%
from tensorflow.keras.preprocessing import image
import pandas as pd

# %%
classe =['P1','P2','P31','P32','P41','P42','P51','P52','P61','P62','P71','P72','P8',]
results = list()

for i in classe:
    img_path =val[val['Sub Position']==i]['Path Crop'].tolist()
    for j in img_path:
        img = image.load_img(j, target_size=(height, width))
            # Convert it to a Numpy array with target shape.
        x = image.img_to_array(img)
            # Reshape
        x = x.reshape((1,) + x.shape)
        x /= 255.
        result = model.predict([x])[0]
        n = 13
        avgDists = result
        idxs = avgDists.argsort()[::-1][:n] #sort max
        predlist,problist = list(), list()
        for m in idxs:
            pred =  classe[m]
            prob = result[m]
            predlist.append(pred)
            problist.append(prob)
        act_true = i
        prob_max = problist[0]
        pred_max = predlist[0]

        results.append({'2Actual':act_true,'3Predicted':pred_max, '4Class_prob':prob_max, '5moreprop':problist[0:3],'6morepred':predlist[0:3],'path':j})

# %%
resultss = pd.DataFrame(results)
resultss
# Out:
#     2Actual 3Predicted  4Class_prob                               5moreprop  \
# 0        P1         P1     0.349313      [0.3493125, 0.3272075, 0.12052132]
# 1        P1        P31     0.251035     [0.25103486, 0.18437493, 0.1366645]
# 2        P1        P61     0.320054    [0.32005435, 0.30902153, 0.26321128]
# 3        P1         P1     0.347869  [0.34786925, 0.122944176, 0.120860465]
# 4        P1        P72     0.262260    [0.26226032, 0.22512123, 0.17950763]
# 5        P1        P41     0.284901     [0.2849009, 0.27640942, 0.20781076]
# 6        P1         P1     0.836325  [0.83632463, 0.059417263, 0.035999645]
# 7        P1         P1     0.579752    [0.5797518, 0.23123562, 0.060672197]
# 8        P1         P1     0.355599    [0.35559896, 0.33450702, 0.09621443]
# 9        P1         P1     0.552869      [0.552869, 0.24436371, 0.12658866]
# 10       P2         P2     0.559962    [0.55996215, 0.14056672, 0.10536921]
# 11       P2        P72     0.318492       [0.31849197, 0.2656039, 0.222959]
# 12       P2        P61     0.327796     [0.32779616, 0.31248474, 0.2563252]
# 13       P2         P2     0.909649   [0.9096488, 0.033586606, 0.031637993]
# 14       P2         P2     0.199928     [0.19992797, 0.1726685, 0.16465273]
# 15       P2         P2     0.715543    [0.71554303, 0.15163706, 0.05520202]
# 16       P2         P2     0.482790    [0.48278952, 0.20295969, 0.15907292]
# 17       P2         P2     0.462710    [0.46270993, 0.24766982, 0.08543712]
# 18       P2         P1     0.480946   [0.48094636, 0.36774015, 0.071146235]
# 19       P2         P2     0.613395    [0.61339486, 0.11905136, 0.07774915]
# 20      P31        P31     0.552779    [0.5527791, 0.40703437, 0.035131797]
# 21      P31        P42     0.805598     [0.8055982, 0.08795299, 0.08258195]
# 22      P31        P31     0.526230    [0.5262297, 0.12925854, 0.095481046]
# 23      P31        P31     0.898217   [0.89821655, 0.073365375, 0.02093447]
# 24      P31        P31     0.951545   [0.9515447, 0.022310337, 0.007465335]
# 25      P31        P31     0.873064    [0.8730644, 0.04735499, 0.028577225]
# 26      P31        P31     0.926316   [0.92631626, 0.03131808, 0.014988337]
# 27      P31        P71     0.685199    [0.6851989, 0.082408935, 0.06743929]
# 28      P31        P31     0.371022     [0.37102234, 0.28106195, 0.2056819]
# 29      P31         P2     0.509880   [0.50987995, 0.31977412, 0.058929075]
# ..      ...        ...          ...                                     ...
# 95      P71        P71     0.492683    [0.49268335, 0.18345383, 0.13372146]
# 96      P71        P71     0.611037     [0.61103725, 0.07737207, 0.0589537]
# 97      P71        P71     0.892361   [0.89236104, 0.07061551, 0.019263418]
# 98      P71        P71     0.777609     [0.77760863, 0.07158418, 0.0682337]
# 99      P71        P71     0.990579  [0.9905793, 0.0045997156, 0.003378537]
# 100     P71        P71     0.944074   [0.9440741, 0.04253342, 0.0066823103]
# 101     P71        P71     0.482971    [0.48297054, 0.17957327, 0.13785389]
# 102     P71        P71     0.994416  [0.9944155, 0.002940897, 0.0011857438]
# 103     P71        P71     0.988161  [0.9881607, 0.005065349, 0.0042766943]
# 104     P71        P71     0.890143     [0.8901426, 0.04216282, 0.01818187]
# 105     P72        P72     0.796142   [0.79614234, 0.118917935, 0.07449733]
# 106     P72        P72     0.889250   [0.88925034, 0.034987573, 0.02655173]
# 107     P72        P32     0.485180       [0.48518, 0.2907483, 0.093233384]
# 108     P72        P72     0.473843     [0.4738432, 0.18983258, 0.13862565]
# 109     P72        P71     0.381300     [0.3813002, 0.21877526, 0.11754952]
# 110     P72         P8     0.436022    [0.43602186, 0.42288908, 0.07481796]
# 111     P72        P72     0.564588     [0.56458783, 0.24991675, 0.1224365]
# 112     P72        P72     0.422126   [0.42212644, 0.42170957, 0.061242595]
# 113     P72         P8     0.386515    [0.38651508, 0.24588926, 0.15770955]
# 114     P72        P72     0.559862     [0.5598618, 0.35724217, 0.04309276]
# 115      P8         P8     0.964734  [0.96473444, 0.02606102, 0.0045849946]
# 116      P8         P8     0.569479      [0.569479, 0.21303916, 0.13267675]
# 117      P8         P8     0.901787  [0.90178746, 0.09018213, 0.0047471714]
# 118      P8         P8     0.829045   [0.82904494, 0.1644073, 0.0023567306]
# 119      P8        P32     0.671013     [0.671013, 0.28640124, 0.012793512]
# 120      P8         P8     0.629961    [0.6299611, 0.32587335, 0.022562848]
# 121      P8         P8     0.818561    [0.8185609, 0.16453578, 0.005883622]
# 122      P8         P8     0.932348    [0.932348, 0.06702574, 0.0003887251]
# 123      P8         P8     0.914698   [0.9146984, 0.08097995, 0.0011842297]
# 124      P8         P8     0.929163    [0.9291625, 0.03114215, 0.023451617]
#
#            6morepred                                               path
# 0      [P1, P41, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1     [P31, P1, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2     [P61, P41, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3     [P1, P72, P71]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4     [P72, P1, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5      [P41, P1, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6      [P1, P2, P61]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7      [P1, P61, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8      [P1, P2, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9      [P1, P41, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10     [P2, P41, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11    [P72, P61, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12     [P61, P1, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13     [P2, P52, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14    [P2, P72, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15     [P2, P1, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16     [P2, P41, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17     [P2, P41, P1]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18     [P1, P2, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19    [P2, P61, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20   [P31, P42, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21   [P42, P41, P51]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22   [P31, P42, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23   [P31, P42, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24   [P31, P61, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25   [P31, P61, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26   [P31, P41, P42]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27   [P71, P52, P42]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28    [P31, P1, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29     [P2, P1, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ..               ...                                                ...
# 95    [P71, P1, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 96    [P71, P52, P8]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 97   [P71, P72, P52]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 98   [P71, P72, P52]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 99    [P71, P72, P8]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 100   [P71, P8, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 101  [P71, P52, P51]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 102  [P71, P72, P52]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 103   [P71, P72, P8]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 104   [P71, P8, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 105  [P72, P52, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 106  [P72, P52, P71]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 107   [P32, P8, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 108  [P72, P32, P52]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 109  [P71, P72, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 110   [P8, P72, P71]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 111  [P72, P71, P52]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 112  [P72, P52, P71]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 113   [P8, P72, P52]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 114   [P72, P52, P2]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 115   [P8, P32, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 116   [P8, P61, P32]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 117   [P8, P32, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 118   [P8, P32, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 119   [P32, P8, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 120   [P8, P32, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 121   [P8, P32, P41]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 122   [P8, P32, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 123   [P8, P32, P72]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 124   [P8, P32, P71]  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
# [125 rows x 6 columns]

# %%
os.chdir( '/home/yupaporn/codes/USAI/')
resultss.to_csv('sub_result1_250_R1.csv')

# %% [markdown]
# # Retrain 2

# %%
# set 'multiply_16' and following layers trainable (Unfreeze --> multiply_16 ) ให้เป็น layers ที่ train ชุดข้อมูลใหม่
conv_base.trainable = True

set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'multiply_15':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
print('This is the number of trainable layers '
      'after freezing the conv base:', len(model.trainable_weights))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=2e-5),
              metrics=['acc'])

#history คือตัวแปรที่จะทำการเก็บประวัติการ Train Model ของเรา
#คำสั่ง Train
tensorboard_cb = callbacks.TensorBoard(run_logdir)
history = model.fit_generator(
      train_generator,#โหลดdataเข้ามา
      steps_per_epoch= NUM_TRAIN //batch_size,
      epochs=epochs,
      validation_data=validation_generator, #validation_data=(x_valid, y_valid): ใส่ data ที่เราแยกไว้เพื่อดูผล Model ว่าเกิด Overfitting เริ่มที่จุดใด
      validation_steps= NUM_TEST //batch_size,
      verbose=1, #โชว์ผลลัพธ์ 0:ปิด
      use_multiprocessing=True, #ใช้ GPU หลายตัว
      workers=1,
      callbacks = tensorboard_cb) #ทำพร้อมกันที่ละ 4 ตัว

# %% [markdown]
# # Test Predict R2

# %% [markdown]
# ### Load model

# %%
import sys
sys.path.append('/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning')

from efficientnet.layers import Swish, DropConnect
from efficientnet.model import ConvKernalInitializer
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({
    'ConvKernalInitializer': ConvKernalInitializer,
    'Swish': Swish,
    'DropConnect':DropConnect
})

# %%
#load model 
from tensorflow.keras.models import load_model
model = load_model("/media/tohn/SSD/Sub_Efficient_USAI/content/efficientnet_keras_transfer_learning/models/Sub_b0_c11_250_R2.h5")

# %% [markdown]
# ### Prediction

# %%
val = df1[df1['Case'].between(1, 10)]

# %%
from tensorflow.keras.preprocessing import image
import pandas as pd

# %%
classe =['P1','P2','P31','P32','P41','P42','P51','P52','P61','P62','P71','P72','P8',]
results = list()

for i in classe:
    img_path =val[val['Sub Position']==i]['Path Crop'].tolist()
    for j in img_path:
        img = image.load_img(j, target_size=(height, width))
            # Convert it to a Numpy array with target shape.
        x = image.img_to_array(img)
            # Reshape
        x = x.reshape((1,) + x.shape)
        x /= 255.
        result = model.predict([x])[0]
        n = 13
        avgDists = result
        idxs = avgDists.argsort()[::-1][:n] #sort max
        predlist,problist = list(), list()
        for m in idxs:
            pred =  classe[m]
            prob = result[m]
            predlist.append(pred)
            problist.append(prob)
        act_true = i
        prob_max = problist[0]
        pred_max = predlist[0]

        results.append({'2Actual':act_true,'3Predicted':pred_max, '4Class_prob':prob_max, '5moreprop':problist[0:3],'6morepred':predlist[0:3],'path':j})

# %%
resultss = pd.DataFrame(results)
resultss
# Out:
#     2Actual 3Predicted  4Class_prob  \
# 0        P1         P1     0.949355
# 1        P1        P31     0.933623
# 2        P1         P1     0.941405
# 3        P1         P1     0.999263
# 4        P1         P1     0.961779
# 5        P1         P1     0.901264
# 6        P1         P1     0.999892
# 7        P1         P1     0.988616
# 8        P1         P1     0.914178
# 9        P1         P1     0.964871
# 10       P2         P2     0.999899
# 11       P2        P61     0.595390
# 12       P2         P2     0.999814
# 13       P2         P2     1.000000
# 14       P2         P2     0.991176
# 15       P2         P2     0.789383
# 16       P2         P2     0.991955
# 17       P2         P2     0.945876
# 18       P2         P2     0.990149
# 19       P2         P2     0.996727
# 20      P31        P31     0.947401
# 21      P31        P42     0.702981
# 22      P31        P31     0.977171
# 23      P31        P31     0.998945
# 24      P31        P31     0.995337
# 25      P31        P31     0.999933
# 26      P31        P31     0.998870
# 27      P31        P42     0.440887
# 28      P31        P31     0.930082
# 29      P31         P1     0.978558
# ..      ...        ...          ...
# 95      P71        P71     0.946082
# 96      P71        P71     0.996272
# 97      P71        P71     0.954517
# 98      P71        P71     0.977151
# 99      P71        P71     0.999975
# 100     P71        P71     0.999877
# 101     P71        P71     0.999260
# 102     P71        P71     0.999985
# 103     P71        P71     0.999766
# 104     P71        P71     0.995604
# 105     P72        P72     0.999096
# 106     P72        P72     0.996427
# 107     P72        P42     0.347824
# 108     P72        P52     0.569424
# 109     P72        P72     0.797035
# 110     P72        P72     0.973632
# 111     P72        P72     0.921755
# 112     P72        P72     0.893894
# 113     P72        P32     0.478303
# 114     P72        P72     0.940866
# 115      P8         P8     0.997415
# 116      P8         P8     0.908559
# 117      P8         P8     0.995986
# 118      P8         P8     0.984249
# 119      P8         P8     0.619963
# 120      P8         P8     0.983763
# 121      P8         P8     0.997437
# 122      P8         P8     0.994175
# 123      P8         P8     0.987957
# 124      P8         P8     0.997342
#
#                                       5moreprop        6morepred  \
# 0         [0.9493551, 0.05031283, 0.0002473657]   [P1, P41, P31]
# 1          [0.9336228, 0.03339171, 0.021122644]   [P31, P1, P42]
# 2          [0.94140506, 0.03018394, 0.01260531]    [P1, P2, P41]
# 3      [0.9992631, 0.0005523312, 7.4508476e-05]    [P1, P61, P2]
# 4         [0.9617787, 0.023765214, 0.011114253]    [P1, P31, P2]
# 5         [0.90126437, 0.08635852, 0.007635688]    [P1, P41, P2]
# 6      [0.99989164, 9.169064e-05, 8.449286e-06]    [P1, P2, P41]
# 7        [0.9886158, 0.005795959, 0.0036222618]   [P1, P61, P31]
# 8         [0.91417843, 0.044570643, 0.03184737]    [P1, P2, P41]
# 9         [0.9648708, 0.02549085, 0.0073609804]    [P1, P2, P41]
# 10     [0.9998994, 8.466036e-05, 5.7853476e-06]    [P2, P41, P1]
# 11       [0.59539014, 0.4040739, 0.00038462775]   [P61, P2, P62]
# 12     [0.999814, 0.00012947217, 2.3200333e-05]    [P2, P61, P1]
# 13     [0.99999976, 1.998914e-07, 4.861912e-08]    [P2, P1, P61]
# 14       [0.9911758, 0.003631198, 0.0019682623]    [P2, P71, P1]
# 15       [0.78938264, 0.20341037, 0.0034839637]    [P2, P1, P61]
# 16     [0.99195486, 0.0069191447, 0.0006313157]   [P2, P41, P31]
# 17         [0.9458764, 0.03977487, 0.013060639]    [P2, P41, P1]
# 18       [0.9901495, 0.009760106, 8.838796e-05]    [P2, P1, P41]
# 19       [0.996727, 0.0016366098, 0.0014628451]    [P2, P1, P52]
# 20       [0.9474012, 0.049056284, 0.0035261323]  [P31, P42, P41]
# 21         [0.7029811, 0.25305557, 0.024761906]  [P42, P41, P51]
# 22       [0.9771708, 0.016974004, 0.0047912453]  [P31, P42, P41]
# 23      [0.9989446, 0.0005460471, 0.0005082656]  [P31, P42, P41]
# 24     [0.99533683, 0.0038375952, 0.0005948522]  [P31, P42, P41]
# 25    [0.9999325, 5.5376666e-05, 1.2016131e-05]  [P31, P42, P41]
# 26       [0.9988703, 0.000844975, 0.0002164024]  [P31, P41, P42]
# 27         [0.44088724, 0.39868236, 0.13687257]  [P42, P41, P31]
# 28        [0.9300817, 0.037883382, 0.029789958]  [P31, P41, P42]
# 29       [0.9785584, 0.015432854, 0.0054364046]    [P1, P41, P2]
# ..                                          ...              ...
# 95       [0.9460822, 0.053429306, 0.0003499461]   [P71, P72, P1]
# 96      [0.9962722, 0.0016776617, 0.0012401296]  [P71, P42, P72]
# 97     [0.95451653, 0.044427913, 0.00095285254]  [P71, P72, P52]
# 98       [0.97715056, 0.011818821, 0.008214186]   [P71, P72, P1]
# 99     [0.9999751, 1.7570093e-05, 7.300093e-06]   [P71, P72, P8]
# 100   [0.99987686, 0.00010959966, 7.044259e-06]  [P71, P72, P52]
# 101      [0.99926025, 0.00031079, 0.0002218271]  [P71, P52, P51]
# 102  [0.99998486, 1.5035296e-05, 1.1241162e-07]  [P71, P72, P52]
# 103  [0.99976605, 0.00023223937, 1.6768063e-06]  [P71, P72, P52]
# 104      [0.9956039, 0.002576443, 0.0007985529]  [P71, P42, P52]
# 105    [0.9990958, 0.00089548324, 8.488806e-06]  [P72, P52, P71]
# 106     [0.996427, 0.0031739017, 0.00037916974]  [P72, P71, P52]
# 107        [0.34782392, 0.19955264, 0.14956297]   [P42, P72, P1]
# 108         [0.56942385, 0.407011, 0.023509745]  [P52, P72, P71]
# 109       [0.7970351, 0.19923502, 0.0018747104]   [P72, P71, P1]
# 110      [0.97363234, 0.02634095, 2.617114e-05]  [P72, P71, P52]
# 111        [0.92175484, 0.06164828, 0.01656256]  [P72, P52, P71]
# 112         [0.8938942, 0.0937547, 0.010093344]  [P72, P52, P71]
# 113        [0.47830278, 0.34353745, 0.12429008]   [P32, P8, P72]
# 114      [0.9408658, 0.057034805, 0.0020994493]  [P72, P52, P71]
# 115    [0.9974148, 0.0025835133, 4.7121227e-07]   [P8, P32, P41]
# 116      [0.90855926, 0.085604556, 0.004414299]   [P8, P32, P61]
# 117      [0.9959863, 0.004012556, 6.624007e-07]   [P8, P32, P72]
# 118     [0.9842493, 0.014760557, 0.00047975543]   [P8, P32, P41]
# 119        [0.61996347, 0.3799749, 3.57206e-05]   [P8, P32, P42]
# 120      [0.9837631, 0.013939367, 0.0011030855]    [P8, P32, P1]
# 121    [0.99743724, 0.002073188, 0.00021717617]   [P8, P32, P41]
# 122     [0.99417526, 0.0058141174, 9.40571e-06]   [P8, P32, P41]
# 123     [0.98795706, 0.011346952, 0.0005463486]   [P8, P32, P42]
# 124     [0.9973424, 0.0026491308, 5.214891e-06]   [P8, P32, P71]
#
#                                                   path
# 0    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 1    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 2    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 3    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 4    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 5    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 6    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 7    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 8    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 9    /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 10   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 11   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 12   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 13   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 14   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 15   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 16   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 17   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 18   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 19   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 20   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 21   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 22   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 23   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 24   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 25   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 26   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 27   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 28   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 29   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# ..                                                 ...
# 95   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 96   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 97   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 98   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 99   /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 100  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 101  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 102  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 103  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 104  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 105  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 106  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 107  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 108  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 109  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 110  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 111  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 112  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 113  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 114  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 115  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 116  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 117  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 118  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 119  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 120  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 121  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 122  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 123  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 124  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
# [125 rows x 6 columns]

# %%
os.chdir( '/home/yupaporn/codes/USAI/')
resultss.to_csv('sub_result1_250_R2.csv')

# %%
# # Directory with our training cat pictures
# validation_P1_dir = os.path.join(validation_dir, 'P1')
# os.makedirs(validation_P1_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P2_dir = os.path.join(validation_dir, 'P2')
# os.makedirs(validation_P2_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P31_dir = os.path.join(validation_dir, 'P31')
# os.makedirs(validation_P31_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P32_dir = os.path.join(validation_dir, 'P32')
# os.makedirs(validation_P32_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P41_dir = os.path.join(validation_dir, 'P41')
# os.makedirs(validation_P41_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P42_dir = os.path.join(validation_dir, 'P42')
# os.makedirs(validation_P42_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P51_dir = os.path.join(validation_dir, 'P51')
# os.makedirs(validation_P51_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P52_dir = os.path.join(validation_dir, 'P52')
# os.makedirs(validation_P52_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P6_dir = os.path.join(validation_dir, 'P6')
# os.makedirs(validation_P6_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P62_dir = os.path.join(validation_dir, 'P62')
# os.makedirs(validation_P62_dir, exist_ok=True)
# validation_P71_dir = os.path.join(validation_dir, 'P71')
# os.makedirs(validation_P71_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P72_dir = os.path.join(validation_dir, 'P72')
# os.makedirs(validation_P72_dir, exist_ok=True)
# # Directory with our training cat pictures
# validation_P8_dir = os.path.join(validation_dir, 'P8')
# os.makedirs(validation_P8_dir, exist_ok=True)

# # Directory with our training cat pictures
# train_P1_dir = os.path.join(train_dir, 'P1')
# os.makedirs(train_P1_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P2_dir = os.path.join(train_dir, 'P2')
# os.makedirs(train_P2_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P31_dir = os.path.join(train_dir, 'P31')
# os.makedirs(train_P31_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P32_dir = os.path.join(train_dir, 'P32')
# os.makedirs(train_P32_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P41_dir = os.path.join(train_dir, 'P41')
# os.makedirs(train_P41_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P42_dir = os.path.join(train_dir, 'P42')
# os.makedirs(train_P42_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P51_dir = os.path.join(train_dir, 'P51')
# os.makedirs(train_P51_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P52_dir = os.path.join(train_dir, 'P52')
# os.makedirs(train_P52_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P6_dir = os.path.join(train_dir, 'P6')
# os.makedirs(train_P6_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P62_dir = os.path.join(train_dir, 'P62')
# os.makedirs(train_P62_dir, exist_ok=True)
# train_P71_dir = os.path.join(train_dir, 'P71')
# os.makedirs(train_P71_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P72_dir = os.path.join(train_dir, 'P72')
# os.makedirs(train_P72_dir, exist_ok=True)
# # Directory with our training cat pictures
# train_P8_dir = os.path.join(train_dir, 'P8')
# os.makedirs(train_P8_dir, exist_ok=True)
