# %%
import pandas as pd
traindf = pd.read_csv (r'/home/yupaporn/codes/USAI/traindf.csv')
validationdf = pd.read_csv (r'/home/yupaporn/codes/USAI/validationdf.csv')
testdf = pd.read_csv (r'/home/yupaporn/codes/USAI/testdf.csv')

# %%
dff = pd.concat([testdf, validationdf,traindf])
print(len(dff))
# Out:
# 6550

# %%
testdf = dff.loc[(dff['fold']==1) | (dff['fold']==2)]
testdf.head(5)
print(len(testdf))
# Out:
# 1325

# %%
validationdf = dff.loc[dff['fold']==5]
validationdf.head(5)
print(len(validationdf))
# Out:
# 656

# %%
traindf = dff.loc[(dff['fold']!=1) & (dff['fold']!=2) &(dff['fold']!=5)]
traindf.head(5)
print(len(traindf))
# Out:
# 4569

# %%
# import os
# os.chdir( '/home/yupaporn/codes/USAI/')
# testdf.to_csv('testdf_fold3.csv')
# validationdf.to_csv('validationdf_fold3.csv')
# traindf.to_csv('traindf_fold3.csv')

# %% [markdown]
# # Train Set

# %%
import pandas as pd
traindf = pd.read_csv (r'/home/yupaporn/codes/USAI/traindf_fold3.csv')
traindf
# Out:
#       Unnamed: 0  Case Abs Position Sub Position     Class Sub_class  \
# 0             34    42           P5          P52  Abnormal      AB01
# 1             35    42           P1           P1  Abnormal      AB02
# 2             36    42           P2           P2  Abnormal      AB02
# 3             37    42           P5          P51  Abnormal      AB02
# 4             38    42           P4          P42  Abnormal      AB02
# ...          ...   ...          ...          ...       ...       ...
# 4567        6544   514           P7          P72    Normal    Normal
# 4568        6545   518           P7          P72    Normal    Normal
# 4569        6546   522           P7          P72    Normal    Normal
# 4570        6547   523           P7          P72    Normal    Normal
# 4571        6548   550           P7          P72    Normal    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
import os
os.chdir('/media/tohn/SSD/Image3/')
# !ls
# Out:
# test  train  validation

# %%
import shutil
dic = {"filename": []}
case = list()

path_train = traindf['Path Crop'].tolist() 
#Train
train_Nor_dir = '/media/tohn/SSD/Image3/train'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    dic["filename"].append(a)
    shutil.copyfile(fname, dst)

# %%
dics = pd.DataFrame(dic)
len(dics)
# Out:
# 4569

# %% [markdown]
# # Validation Set

# %%
validationdf = pd.read_csv (r'/home/yupaporn/codes/USAI/validationdf_fold3.csv')
validationdf
# Out:
#      Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0            19            53    22           P2           P2  Abnormal
# 1            20            54    22           P1           P1  Abnormal
# 2            21            55    22           P4          P42  Abnormal
# 3            22            56    22           P3          P31  Abnormal
# 4            23            57    22           P4          P41  Abnormal
# ..          ...           ...   ...          ...          ...       ...
# 651        4548          6522   501           P7          P72    Normal
# 652        4552          6526   492           P7          P72    Normal
# 653        4559          6535   543           P7          P72    Normal
# 654        4562          6539   559           P7          P72    Normal
# 655        4564          6541   535           P7          P72    Normal
#
#     Sub_class                                          Path Full  \
# ...

# %%
import shutil
dic = {"filename": []}
case = list()

path_train = validationdf['Path Crop'].tolist() 
#Train
train_Nor_dir = '/media/tohn/SSD/Image3/validation'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    dic["filename"].append(a)
    shutil.copyfile(fname, dst)

# %%
dics = pd.DataFrame(dic)
len(dics)
# Out:
# 654

# %% [markdown]
# # Test Set

# %%
testdf = pd.read_csv (r'/home/yupaporn/codes/USAI/testdf_fold3.csv')
testdf
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0           111    40           P1           P1  Abnormal
# 1              1           112    40           P2           P2  Abnormal
# 2              2           113    40           P4          P41  Abnormal
# 3              3           114    40           P5          P51  Abnormal
# 4              4           115    40           P3          P31  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 1320        1320          6479   635           P7          P72    Normal
# 1321        1321          6492   609           P7          P72    Normal
# 1322        1322          6494   621           P7          P72    Normal
# 1323        1323          6517   556           P7          P72    Normal
# 1324        1324          6530   601           P7          P72    Normal
#
#      Sub_class                                          Path Full  \
# ...

# %%
import shutil
dic = {"filename": []}
case = list()

path_train = testdf['Path Crop'].tolist() 
#Train
train_Nor_dir = '/media/tohn/SSD/Image3/test'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    dic["filename"].append(a)
    shutil.copyfile(fname, dst)

# %%
dics = pd.DataFrame(dic)
len(dics)
# Out:
# 1325
